# %% [markdown]
# # vars-kb-server
#
# This is a RESTful read-only service for retrieving information from MBARI's knowledgebase (KB). The source code is available at <https://github.com/underwatervideo/vars-kb-server>. MBARI has a public knowledgebase available at <http://dsg.mbari.org>

# %% [markdown]
# ### Define URLs

# %%
endpoint = "http://dsg.mbari.org/kb/v1"

concept_url = "%s/concept" % (endpoint)
phylogeny_url = "%s/phylogeny" % (endpoint)
links_url = "%s/links" % (endpoint)

# %% [markdown]
# ### Configure imports and define helper functions

# %%
import datetime
import json
import pprint
import random
import requests
import urllib
import uuid

def show(s, data = None):
    pp = pprint.PrettyPrinter(indent=1)
    print("--- " + s)
    if data:
      pp.pprint(data)
    
def iso8601():
    return datetime.datetime.now(datetime.timezone.utc).isoformat()[0:-6] + "Z"
    
def parse_response(r):
    try:
       return json.loads(r.text)
    except:
        s = "URL: %s\n%s (%s): %s" % (r.request.url, r.status_code, r.reason, r.text)
        print(s)
        return {}
    
    
def delete(url):
    return parse_response(requests.delete(url))

def get(url):
    return parse_response(requests.get(url))
    
def post(url, data = {}):
    return parse_response(requests.post(url, data))

def put(url, data = {}):
    return parse_response(requests.put(url, data))

# %% [markdown]
# ## Concept API
#
# This API is for fetching a listing of all available concepts AND details about a particular concept

# %%
# Fetch the names of all concepts
concepts = get(concept_url)
show("GET: " + concept_url, concepts)
# Out:
# --- GET: http://dsg.mbari.org/kb/v1/concept
# ['1-gallon paint bucket',
#  '2G Robotics structured light laser',
#  '55-gallon drum',
#  "a'a",
#  'abandoned research equipment',
#  'Abraliopsis',
#  'Abraliopsis felis',
#  'abyssal',
#  'abyssal grenadier',
#  'abyssal snailfish',
#  'Abyssochrysidae',
#  'Abyssochrysoidea',
#  'Abyssocucumis',
#  'Abyssocucumis abyssorum',
#  'Acanella',
#  'Acanthamunnopsis',
#  'Acanthamunnopsis milleri',
#  'Acanthascinae',
#  'Acanthascinae sp. 1',
#  'Acanthascinae sp. 2',
#  'Acanthascinae sp. 3',
#  'Acanthephyra',
#  'Acanthogorgia',
#  'Acanthogorgiidae',
#  'Acanthohamingia',
#  'Acantholiparis',
#  'Acanthoptilum',
#  'Acanthuridae',
#  'Acanthurus',
#  'Acanthurus xanthopterus',
#  'Acesta',
#  'Acesta mori',
#  'Acesta sphoni',
#  'Acharax',
#  'Aciculata',
#  'ACM',
#  'Acoetidae',
#  'Acontiaria',
#  'acorn worm',
#  'Acoustic Current Meter',
#  'Acoustic Doppler Current Profiler',
#  'Acoustic Probe',
#  'Acrocirridae',
#  'Acrosphaera',
#  'Actinauge',
#  'Actinauge verrillii',
#  'Actinernidae',
#  'Actinernoidea',
#  'Actinernus',
#  'Actiniaria',
#  'Actiniaria incertae sedis',
#  'Actiniidae',
#  'Actiniidae sp. 1',
#  'Actinioidea',
#  'Actinommidae',
#  'Actinopteri',
#  'Actinopterygii',
#  'Actinoscyphia',
#  'Actinoscyphiidae',
#  'Actinostola',
#  'actinostolid anemone',
#  'Actinostolidae',
#  'Actinostoloidea',
#  'ADCP',
#  'adhesive',
#  'Aegina',
#  'Aegina citrea',
#  'Aegina rosea',
#  'Aeginidae',
#  'Aeginura',
#  'Aeginura grimaldii',
#  'Aeolidiidae',
#  'Aequorea',
#  'Aequorea aequorea',
#  'Aequorea victoria',
#  'Aequoreidae',
#  'Aetideidae',
#  'Agalma',
#  'Agalmatidae',
#  'Agalmidae',
#  'Aglantha',
#  'Aglantha digitale',
#  'Aglaophenia',
#  'Aglaura',
#  'Agnatha',
#  'Agonidae',
#  'air',
#  'Alaria',
#  'Alaria marginata',
#  'Alariaceae',
#  'albatross',
#  'Albatrossia',
#  'Albatrossia pectoralis',
#  'Alcidae ',
#  'Alciopa',
#  'Alciopa reynaudii',
#  'alciopid worm',
#  'Alciopidae',
#  'Alcyonacea',
#  'Alcyonaria',
#  'Alcyoniidae',
#  'Alcyoniina',
#  'Aldrovandia',
#  'Aldrovandia phalacra',
#  'Alepisauridae',
#  'Alepisaurus',
#  'Alepisaurus ferox',
#  'Alepocephalidae',
#  'Alepocephalus',
#  'Alepocephalus tenebrosus',
#  'Alia',
#  'Alia permodesta',
#  'alkalic basalt',
#  'Allapasus',
#  'Allapasus aurianticus',
#  'Allapasus sp. 1',
#  'Allapasus sp. 2',
#  'Allapasus sp. 3',
#  'alligatorfish',
#  'Allocentrotus',
#  'Allocentrotus fragilis',
#  'Allopora',
#  'Allopora californica',
#  'Alloposidae',
#  'Almaco jack',
#  'Alopias',
#  'Alopiidae',
#  'Alvinella',
#  'Alvinella caudata',
#  'Alvinella pompejana',
#  'Alvinellidae',
#  'Alvinellinae',
#  'amberjack',
#  'Amblyraja',
#  'Amblyraja badia',
#  'Ammothea',
#  'Ammothea verenae',
#  'Ammotheidae',
#  'Ampharetidae',
#  'Amphascandria',
#  'Ampheraster',
#  'Ampheraster marianus',
#  'amphibole',
#  'amphibolite',
#  'Amphicaryon',
#  'Amphicaryon acaule',
#  'Amphicaryon ernesti',
#  'Amphicaryon peltifera',
#  'Amphicaryoninae ',
#  'Amphidiscella',
#  'Amphidiscella lecus',
#  'Amphidiscophora',
#  'Amphidiscosida',
#  'Amphigona',
#  'Amphigona apicata',
#  'Amphinema',
#  'Amphinema platyhedos',
#  'Amphineura',
#  'amphinomid worm',
#  'Amphinomida',
#  'Amphinomidae',
#  'amphipod tube mat',
#  'Amphipoda',
#  'Amphisamytha',
#  'Amphisamytha galapagensis',
#  'Amphitrite',
#  'AMT',
#  'Anarhichadidae',
#  'Anarrhichthys',
#  'Anarrhichthys ocellatus',
#  'Anaspidea',
#  'Anchinothria',
#  'Anchinothria fissurata',
#  'anchor',
#  'anchovy',
#  'Ancistrocheiridae',
#  'Ancistrocheirus',
#  'Ancistrocheirus lesueurii ',
#  'Andersen`s lantern fish',
#  'andesite',
#  'anemone',
#  'anemonefish',
#  'Anenthemonae',
#  'angel shark',
#  'angler shrimp',
#  'anglerfish',
#  'Anguilliformes',
#  'anhydrite',
#  'Animalia',
#  'Anisotremus',
#  'anisotremus',
#  'Anisotremus davidsonii',
#  'Anisotremus interruptus',
#  'Annatiara',
#  'Annatiara affinis',
#  'annelid',
#  'Annelida',
#  'Anomura',
#  'Anoplogaster',
#  'Anoplogaster cornuta',
#  'Anoplogasteridae',
#  'Anoplopoma',
#  'Anoplopoma fimbria',
#  'Anoplopomatidae',
#  'Anotopteridae',
#  'Anotopterus',
#  'Anotopterus nikparini',
#  'Anseropoda',
#  'Anseropoda insignis',
#  'Antedonacea',
#  'Antedonidae',
#  'Antedonoidea',
#  'Anteliaster',
#  'antenna',
#  'Anthiinae',
#  'Anthoathecata',
#  'Anthomastus',
#  'Anthomastus ritteri',
#  'Anthomastus robustus',
#  'Anthoptilidae',
#  'Anthoptilum',
#  'Anthoptilum grandiflorum',
#  'Anthoptilum lithophilum',
#  'Anthosactis',
#  'Anthosactis nomados',
#  'Anthosactis pearseae',
#  'Anthozoa',
#  'Antimora',
#  'Antimora microlepis',
#  'Antipatharia',
#  'Antipathes',
#  'Antipathes dendrochristos',
#  'Antipathidae',
#  'Anuropidae',
#  'Anuropus',
#  'Anuropus bathpelagicus',
#  'apatite',
#  'aperture',
#  'Aphragmophora',
#  'Aphrocallistidae',
#  'Aphroditidae',
#  'Aphroditiformia',
#  'Aphyonidae',
#  'Apistobranchidae',
#  'Aplacophora',
#  'Aplanulata',
#  'Aplousobranchia',
#  'Aplysia',
#  'Aplysia californica',
#  'Aplysiidae',
#  'Aplysioidea',
#  'Apogon',
#  'Apogon pacificus',
#  'Apogon retrosella',
#  'Apogonidae',
#  'Apogoninae',
#  'Apolemia',
#  'Apolemia lanosa',
#  'Apolemia rubriversa',
#  'Apolemia uvaria',
#  'Apolemiidae',
#  'Aporocidaris',
#  'Aporocidaris milleri',
#  'Apostichopus',
#  'Apostichopus californicus',
#  'Apostichopus leukothele',
#  'Apostichopus sp. 1',
#  'appendage',
#  'Appendicularia',
#  'apple anemone',
#  'Apristurus',
#  'Apristurus brunneus',
#  'Apristurus kampae',
#  'Apristurus spongiceps',
#  'Aprodon',
#  'Aprodon cortezianus',
#  'Arachnactidae',
#  'Arachnactis',
#  'Araeosoma',
#  'Araeosoma leptaleum',
#  'aragonite',
#  'Archaea',
#  'Archeterokrohnia',
#  'Archeterokrohnia docrickettsae',
#  'Archivesica',
#  'Archivesica gigas',
#  'Arcoscalpellinae',
#  'Arctapodema',
#  'Arctozenus',
#  'Arctozenus risso',
#  'Arenicolidae',
#  'Argentina',
#  'Argentina sialis',
#  'argentine',
#  'Argentinidae',
#  'argillite',
#  'Argonautoidea',
#  'Argus moray',
#  'Argyropelecus',
#  'Argyropelecus affinis',
#  'Argyropelecus pacificus',
#  'Arhynchobatidae',
#  'Arhynchobatidae sp. A',
#  'Arhynchobatidae sp. B',
#  'Ariomma',
#  'Ariommatidae',
#  'ariommatids',
#  'Aristeidae',
#  'Aristostomias',
#  'Aristostomias scintillans',
#  'Arkosic sandstone',
#  'arm',
#  'armed box crab',
#  'armored gurnard',
#  'armored searobin',
#  'armoured redmouthed whalefish',
#  'arrange',
#  'arrow flounder',
#  'arrow worm',
#  'arrowtooth flounder',
#  'Arthropoda',
#  'Articulata',
#  'Artostrobiidae',
#  'Asbestopluma',
#  'Asbestopluma biserialis',
#  'Asbestopluma monticola',
#  'Asbestopluma rickettsi',
#  'Asbestopluma sp. A',
#  'Ascidiacea',
#  'ascidian',
#  'Ascophora',
#  'Asellota',
#  'ash',
#  'Aspidochirotida',
#  'Astacidea',
#  'Asteriidae',
#  'Asterina',
#  'Asterina miniata',
#  'Asterinidae',
#  'asteroid feeding depression',
#  'Asteroidea',
#  'Asteroidea sp. 1',
#  'Asteroidea sp. 2',
#  'Asteroidea sp. 3',
#  'Asteroidea sp. 4',
#  'Asteroidea sp. 5',
#  'Asteroidea sp. 6',
#  'Asteroidea sp. 7',
#  'Asteroidea sp. 8',
#  'Asteroidea sp. 9',
#  'Asteronychidae',
#  'Asteronyx',
#  'Asteronyx longifissus',
#  'Asteronyx loveni',
#  'Asterophila',
#  'Asterophila rathbunasteri',
#  'Asteropseidae',
#  'Asteropsidae',
#  'Asterozoa',
#  'Asthenactis',
#  'Asthenactis fisheri',
#  'Asthenactis papyraceus',
#  'Astracanthidae',
#  'Astronesthes',
#  'Astronesthes nigroides',
#  'Astronesthinae',
#  'Astropecten',
#  'Astropectinidae',
#  'Astrophorida',
#  'Astrorhizida',
#  'Astyris permodesta',
#  'Atelostomata',
#  'Athenaria',
#  'Atheresthes',
#  'Atheresthes stomias',
#  'Atlanticellidae',
#  'Atlantisella',
#  'Atolla',
#  'Atolla gigantea',
#  'Atolla parva',
#  'Atolla vanhoeffeni',
#  'Atolla wyvillei',
#  'Atollidae',
#  'Atorella',
#  'Atorella octogonus',
#  'Atorellidae',
#  'attenuated spider fish',
#  'Aulacanthidae',
#  'Aulacoctena',
#  'Aulacoctena acuminata',
#  'Aulopidae',
#  'Aulopiformes',
#  'Aulopus',
#  'Aulosphaera',
#  'Aulosphaeridae',
#  'Aurelia',
#  'Aurelia aurita',
#  'Aureliinae',
#  'auricle',
#  'aurora rockfish',
#  'authigenic carbonate',
#  'Autonomous Monitoring Transponder',
#  'autonomous underwater vehicle',
#  'AUV',
#  'Aux camera',
#  'Aves',
#  'Avocettina',
#  'Avocettina bowersii',
#  'Axiidae ',
#  'Axioidea',
#  'Bacillariophyceae',
#  'back deck',
#  'Bacteria',
#  'bacterial mat',
#  'bait',
#  'Balaenopteridae',
#  'Balanophyllia',
#  'Balanophyllia elegans',
#  'baleen whale',
#  'Balistidae',
#  'ball',
#  'balloon',
#  'bamboo coral',
#  'bank rockfish',
#  'Barathrites',
#  'Barathrites parri',
#  'barberfish',
#  'Barbourisia',
#  'Barbourisia rufa',
#  'Barbourisiidae',
#  'Bargmannia',
#  'Bargmannia amoena',
#  'Bargmannia elongata',
#  'Bargmannia lata',
#  'barite',
#  'barnacle',
#  'barracuda',
#  'barracudina',
#  'barred serrano',
#  'barrel amphipod',
#  'barreleye',
#  'barreleye fish',
#  'Barry',
#  'barspot cardinalfish',
#  'basalt',
#  'basaltic andesite',
#  'basaltic lava',
#  'basket star',
#  'basketweave cusk eel',
#  'Bassozetus',
#  'Bassozetus nasus',
#  'bat ray',
#  'bat star',
#  'batfish',
#  'Bathochordaeinae',
#  'Bathochordaeus',
#  'Bathochordaeus charon',
#  'Bathochordaeus mcnutti',
#  'Bathochordaeus sinker',
#  'Bathochordaeus sp. A',
#  'Bathochordaeus stygius',
#  'Bathocyroe',
#  'Bathocyroe fosteri',
#  'Bathocyroidae',
#  'Bathophilus',
#  'Bathophilus brevis',
#  'Bathophilus filifer',
#  'Bathophilus flemingi',
#  'Bathyagoninae',
#  'Bathyagonus',
#  'Bathyagonus alascanus',
#  'Bathyagonus infraspinatus',
#  'Bathyagonus nigripinnis',
#  'Bathyagonus pentacanthus',
#  'bathyal',
#  'Bathyalcyon',
#  'Bathyalcyon robustum',
#  'Bathybembix',
#  'Bathybembix bairdii',
#  'Bathyceramaster',
#  'Bathyceramaster careyi',
#  'Bathyceramaster elegans',
#  'Bathycongrus',
#  'Bathycongrus macrurus',
#  'Bathycrinidae',
#  'Bathycrinidae sp. 1',
#  'Bathycrinus',
#  'Bathyctena',
#  'Bathyctena chuni',
#  'Bathyctenidae',
#  'Bathydorididae',
#  'Bathydoris aioca',
#  'Bathydorus',
#  'Bathydorus laevis spinosus',
#  'Bathydorus laniger',
#  'Bathydorus sp. 1',
#  'Bathygadinae',
#  'Bathykurila',
#  'Bathykurila guaymasensis',
#  'Bathylagidae',
#  'Bathylagoides',
#  'Bathylagoides wesethi',
#  'Bathylagus',
#  'Bathylagus milleri',
#  'Bathylagus ochotensis',
#  'Bathylagus pacificus',
#  'Bathylagus stilbius',
#  'Bathylagus wesethi',
#  'Bathymetrinae',
#  'Bathyopsurinae',
#  'Bathyopsurus',
#  'Bathypathes',
#  'Bathypathes alternata',
#  'Bathyphellia',
#  'Bathyphellia australis',
#  'Bathyphellidae',
#  'Bathyphysa',
#  'Bathyphysa conifera',
#  'Bathyplotes',
#  'Bathypolypodinae',
#  'Bathyporania',
#  'Bathyporania ascendens',
#  'Bathypteroidae',
#  'Bathypterois',
#  'Bathypterois atricolor',
#  'Bathypterois grallator',
#  'Bathypterois pectinatus',
#  'Bathyraja',
#  'Bathyraja abyssicola',
#  'Bathyraja cf. microtrachys',
#  'Bathyraja kincaidii',
#  'Bathyraja microtrachys',
#  'Bathyraja spinosissima',
#  'Bathyraja trachura',
#  'Bathysauridae',
#  'Bathysaurus',
#  'Bathysaurus mollis',
#  'Bathysiphon',
#  'Bathysiphoninae',
#  'Bathyspadella',
#  'Bathyspadellidae',
#  'Bathyteuthidae',
#  'Bathyteuthis',
#  'Bathyteuthis abyssicola',
#  'Bathyteuthis berryi',
#  'Batrachoididae',
#  'Batrachoidiformes',
#  'battery',
#  'battery cage',
#  'bay goby',
#  'beacon',
#  'bead',
#  'beak',
#  'beaker',
#  'bearded eelpout',
#  'BED',
#  'bedding',
#  'Beggiatoa',
#  'Beggiatoaceae',
#  'Beggiatoales',
#  'behavior',
#  'bell',
#  'Belonella',
#  'Belonella borealis',
#  'Beloniformes',
#  'benmoreite',
#  'Benthalbella',
#  'Benthalbella dentata',
#  'Benthalbella linguidens',
#  'Benthesicymidae',
#  'Bentheuphausia',
#  'Bentheuphausia amblyops',
#  'Bentheuphausiidae',
#  'benthic barrel',
#  'benthic boundary layer',
#  'benthic event detector',
#  'Benthic Flux Chamber',
#  'Benthic Flux Lander',
#  'benthic foraminifera',
#  'Benthic Instrument Node',
#  'benthic jelly',
#  'benthic microbial fuel cell',
#  'benthic mooring',
#  'Benthic Respiration Chamber',
#  'Benthic Respiration System',
#  'Benthic Rover',
#  'benthic siphonophore',
#  'benthic zone',
#  'Benthocodon',
#  'Benthocodon hiatus',
#  'Benthocodon pedunculata',
#  'Benthoctopus',
#  'Benthoctopus abruptus',
#  'Benthoctopus leioderma',
#  'Benthoctopus robustus',
#  'Benthoctopus sp. 1',
#  'Benthodytes',
#  'Benthodytes aff. typica',
#  'Benthodytes sanguinolenta',
#  'Benthodytes sp. 1',
#  'Benthogone',
#  'Benthopecten',
#  'Benthopecten claviger',
#  'Benthopectinidae',
#  'benthos',
#  'Benthos spheres',
#  'Benthosema',
#  'Benthosema panamense',
#  'Benthoteuthis',
#  'Benthothuria',
#  'benttooth bristlemouth',
#  'Beringraja',
#  'Beringraja binoculata',
#  'Beroe',
#  'Beroe abyssicola',
#  'Beroe cucumis',
#  'Beroe forskalii',
#  'Beroe gracilis',
#  'Beroida',
#  'Berryteuthis',
#  'Berryteuthis anonychus',
#  'Beryciformes',
#  'Bett Type 4',
#  'bicolored bristlemouth',
#  'Bidenichthys',
#  'Bifaxariidae',
#  'Bifaxarioidea',
#  'big red',
#  'big skate',
#  'big ugly',
#  'bigeye eualid',
#  'bigeye fish',
#  'bigeye lanternfish',
#  'bigeye lightfish',
#  'bigeye poacher',
#  'bigeye starsnout poacher',
#  'bigfin eelpout',
#  'bigfin lanternfish',
#  'Bigmouth sole',
#  'bigpored snailfish',
#  'bigscale',
#  'BIN',
#  'Bio tube',
#  'biogenic carbonate',
#  'biological structure',
#  'Biology box',
#  'bioluminesce',
#  'Bioluminescent Camera',
#  'Bioluminescent screen',
#  'biotite',
#  'bioturbation',
#  'bioturbation uncategorized',
#  'bird',
#  'Bird water sampler',
#  'Biremis',
#  'Birsteiniamysis',
#  'Birsteiniamysis inermis',
#  'bitumen',
#  'bivalve',
#  'Bivalvia',
#  'black barracudina',
#  'black cod',
#  'black coral',
#  'black dragonfish',
#  'black eelpout',
#  'black eyed squid',
#  'black frame',
#  'black hagfish',
#  'black lampfish',
#  'black rockfish',
#  'black skate',
#  'black smoker',
#  'black swallower',
#  'blackbelly dragonfish',
#  'blackbelly eelpout',
#  'blackbelly pearleye',
#  'blackeye goby',
#  'blackfin poacher',
#  'blackfin starsnout poacher',
#  'blackgill rockfish',
#  'blackmouth eelpout',
#  'blacktail snailfish',
#  'blacktip poacher',
#  'blade',
#  'blob sculpin',
#  'block',
#  'blue lanternfish',
#  'blue rockfish',
#  'blue shark',
#  'blue-and-yellow chromis',
#  'blue-green algae',
#  'bluebarred prickleback',
#  'bluefin driftfish',
#  'bluntnose sevengill shark',
#  'bluntnose sixgill shark',
#  'BMFC',
#  'bobtail eel',
#  'bobtail snipe eel',
#  'bocaccio',
#  'Bodianus',
#  'Bodianus diplotaenia',
#  'body',
#  'Bolinopsidae',
#  'Bolinopsis',
#  'Bolinopsis infundibulum',
#  'Bolitaena',
#  'Bolitaenidae',
#  'Bolocera',
#  'Bolocera kensmithi',
#  'Bolosominae',
#  'Boltenia',
#  'bone',
#  'Bonelliida',
#  'Bonelliidae',
#  'Bonetree',
#  'bonito',
#  'boreal clubhook squid',
#  'Boreomysis',
#  'Boreomysis californica',
#  'Bothidae',
#  'Bothrocara',
#  'Bothrocara brunneum',
#  'Bothrocara molle',
#  'botryllidae',
#  'Botrynema',
#  'Botrynema brucei',
#  'bottle',
#  'bottle-2',
#  'bottlelight',
#  'bottom mount',
#  'Bougainvilliidae',
#  'boulder',
#  'boundary',
#  'Bourgueticrinida',
#  'Bourgueticrinina',
#  'Box corer',
#  'Brachiopod basket',
#  'Brachiopod Settlement Block',
#  'Brachiopoda',
#  'Brachyura',
#  'bract',
#  'Branchinotogluma',
#  'Branchinotogluminae',
#  'Branchiocerianthus',
#  'Branchiocerianthus imperator',
#  'branchiopod',
#  'Branchiopoda',
#  'breccia',
#  'Bregmaceros',
#  'Bregmaceros bathymaster',
#  'Bregmacerotidae',
#  'briefcase',
#  'Brisaster',
#  'Brisaster latifrons',
#  'Brisaster townsendi',
#  'Brisinga',
#  'Brisingida',
#  'Brisingidae',
#  'bristle',
#  'bristlemouth',
#  'brittlestar',
#  'broad skate',
#  'broadfin lampfish',
#  'bronzespotted rockfish',
#  'brooding',
#  'broom',
#  'Brosmophycinae',
#  'brotula',
#  'brotulid',
#  'Brotulidae',
#  'brown algae',
#  'brown box crab',
#  'brown catshark',
#  'brown rudderfish',
#  'Brown Sea Cucumber',
#  'brown smoothhound',
#  'BRS',
#  'Bryopsidales',
#  'Bryozoa',
#  'bryozoan',
#  'Bubble Chamber',
#  'Bubble Meter',
#  'bubblegum coral',
#  'bubbles',
#  'bubbling',
#  'Buccinidae',
#  'Buccinoidea',
#  'Buccinum',
#  'bucket',
#  'bull kelp',
#  'bulldog snailfish',
#  'Bullseye level',
#  'Bumpy',
#  'burrito grunt',
#  'burrow',
#  'burrowing',
#  'burrowing anemone',
#  'Bush, Stephanie',
#  'butt worm',
#  'butterfish',
#  'butterflyfish',
#  'by-the-wind-sailor',
#  'Bythitidae',
#  'Bythitinae',
#  'Bythograea',
#  'Bythograea thermydron',
#  'Bythograeidae',
#  'Bythograeoidea',
#  'Bythotiara',
#  'Bythotiara depressa',
#  'Bythotiara dolioeques',
#  'c-o turbot',
#  'cabezon',
#  'cable',
#  'cable spool',
#  'cable tracker',
#  'Cable-laying toolsled',
#  'Caecosagitta',
#  'Caecosagitta macrocephala',
#  'Caenogastropoda',
#  'cage',
#  'caisson',
#  'Calanidae',
#  'Calanoida',
#  'Calantica',
#  'Calantica moskalevi',
#  'Calanticidae',
#  'Calanus',
#  'Calappidae',
#  'Calappoidea',
#  'Calcarea',
#  'Calcaronea',
#  'Calcaxonia',
#  'Calcinea',
#  'calcite',
#  'caldera',
#  'calibrator',
#  'calico lizardfish',
#  'calico rockfish',
#  'California barracuda',
#  'California bigeye octopus',
#  'California flashlightfish',
#  'California grenadier',
#  'California halibut',
#  'California headlightfish',
#  'California hydrocoral',
#  'California king crab',
#  'California lanternfish',
#  'California lizardfish',
#  'California market squid',
#  'California sardine',
#  'California sea cucumber',
#  'California sea lion',
#  'California skate',
#  'California slickhead',
#  'California smoothtongue',
#  'Callianassidae',
#  'Calliarthron',
#  'Calliarthron tuberculosum',
#  'Calliderma',
#  'Calliderma emma',
#  'Calliostoma',
#  'Calliostoma platinum',
#  'Calliostomatidae',
#  'Calliotropidae',
#  'Calocarides',
#  'Calocarides quinqueseriatus',
#  'Calycophorae',
#  'Calycopsidae',
#  'Calycopsis',
#  'Calycopsis simulans',
#  'Calyptogena',
#  'Calyptogena diagonalis',
#  'Calyptogena elongata',
#  'Calyptogena extenta ',
#  'Calyptogena gigas',
#  'Calyptogena kilmeri',
#  'Calyptogena magnifica',
#  'Calyptogena pacifica',
#  'Calyptogena packardana',
#  'Calyptrophora',
#  'Calyptrophora antilla',
#  'Calyptrophora bayeri',
#  'Calyptrophora laevispinosa',
#  'Camarodonta',
#  'camera',
#  'camera tripod',
#  'camera-transport',
#  'Campanulariidae',
#  'Camptonectinae',
#  'can',
#  'Canalipalpata',
#  'canary rockfish',
#  'Cancellothyrididae',
#  'Cancer',
#  'Cancer magister',
#  'Cancridae',
#  'Cancridae sp. 1',
#  'Cancroidea',
#  'Candelabridae',
#  'Candelabridae sp. 1',
#  'canister',
#  'Cannobotryidae',
#  'Cannosphaeridae',
#  'canyon',
#  'Capitata',
#  'Capitellidae',
#  'Caprella',
#  'Caprellidae',
#  'Caprellidea',
#  'Caprelloidea',
#  'Carangidae',
#  'carapace',
#  'carbon dioxide',
#  'carbon dioxide hydrate',
#  'carbonate',
#  'carbonate mineral',
#  'carbonate sandstone',
#  'carcass',
#  'Carcharhinidae',
#  'Carcharhiniformes',
#  'Carcharodon',
#  'Carcharodon carcharias',
#  'cardboard',
#  'Cardiapoda',
#  'Cardiapoda placenta',
#  'Careproctus',
#  'Careproctus filamentosus',
#  'Careproctus gilberti',
#  'Careproctus kamikawai',
#  'Careproctus longifilis',
#  'Careproctus melanurus',
#  'Careproctus microstomus',
#  'Careproctus ovigerum',
#  'Careproctus ovigerus',
#  'Caridea',
#  'Caridea sp. 1',
#  'Caridea sp. 2',
#  'Carinacea',
#  'Carinaria',
#  'Carinaria japonica',
#  'Carinariidae',
#  'Carnivora',
#  'carnivore',
#  'Caryophyllia',
#  'Caryophyllia diomedeae',
#  'Caryophylliidae',
#  'Cassiduloida',
#  'Castanellidae',
#  'Cataegidae',
#  'Cataegis',
#  'Cataegis myronfeinbergi',
#  'Cataetyx',
#  'catshark',
#  'Catulus brunneus',
#  'Caulophacidae',
#  'Caulophacus',
#  'Caulophacus cyanae',
#  'cave',
#  'Cavolinia',
#  'Cavolinia tridentata',
#  'Cavoliniidae',
#  'Cavolinioidea',
#  'Caymanostellidae',
#  'CCE BIN',
#  'Centrolophidae',
#  'Cephalaspidomorphi',
#  'Cephalopoda',
#  'Cephalopyge',
#  'Cephalopyge trematoides',
#  'Cephalurus',
#  'Cephalurus cephalus',
#  'Ceramaster',
#  'Ceramaster clarki',
#  'Ceramaster patagonicus',
#  'Ceramaster pointsurae',
#  'Ceramiales',
#  'Cerataspis',
#  'Cerataspis monstruosus',
#  'Ceratoscopelus',
#  'Ceratoscopelus townsendi',
#  'Cercozoa',
#  'Ceriantharia',
#  'Ceriantharia sp. 1',
#  'Ceriantharia sp. 2',
#  'Ceriantharia sp. 3',
#  'Cerianthidae',
#  'Cestida',
#  'Cestidae',
#  'Cestum',
#  'Cestum veneris',
#  'Cetacea',
#  'cetacean',
#  'Cetomimidae',
#  'Cetomimiformes',
#  'Cetostoma',
#  'Cetostoma regani',
#  'Chaenophryne',
#  'Chaenophryne longiceps',
#  'Chaenophryne melanorhabdus',
#  'Chaetodon',
#  'Chaetodon humeralis',
#  'Chaetodontidae',
#  'Chaetognatha',
#  'Chaetopteridae',
#  'Chaetopterus',
#  'Chaetopterus pugaporcinus',
#  'chalcopyrite',
#  'Challengeridae',
#  'chameleon rockfish',
#  'channel',
#  'char',
#  'Charadriiformes',
#  'charcoal codling',
#  'Charistephane',
#  'Charistephane fugiens',
#  'Chauliodontinae',
#  'Chauliodus',
#  'Chauliodus macouni',
#  'Chaunacidae',
#  'Chaunacops',
#  'Chaunacops coloratus',
#  'Chauvinelia',
#  'Cheilostomata ',
#  'Cheilostomatida ',
#  'Chelicerata',
#  'cheliped',
#  'chemical',
#  'Chemical Scanner',
#  'Chemoattractant',
#  'chert',
#  'Cherublemma',
#  'Cherublemma emmelas',
#  'Chiarella',
#  'Chiarella centripetalis',
#  'Chiasmodon',
#  'Chiasmodon niger',
#  'Chiasmodontidae',
#  'Chilara',
#  'Chilara taylori',
#  'chilipepper',
#  'Chilophiurina',
#  'chimaera',
#  'Chimaeridae',
#  'Chimaeriformes',
#  'chimney',
#  'chimney inactive',
#  'china rockfish',
#  'Chionoecetes',
#  'Chionoecetes opilio',
#  'Chionoecetes tanneri',
#  'Chirostylidae',
#  'Chirostyloidea',
#  'Chiroteuthidae',
#  'Chiroteuthis',
#  'Chiroteuthis calyx',
#  'chiton',
#  'chlorite',
#  'Chlorophyta',
#  'Chondrichthyes',
#  'Chondrocladia',
#  'Chondrocladia lyra',
#  'Chondrocladia sp. 1',
#  'Chondrocladia sp. 4',
#  'Chondrocladia sp. A',
#  'Chonelasma',
#  'Chonelasmatinae',
#  'Chordata',
#  'Chorilia',
#  'Chorilia longipes',
#  'Chromatonema',
#  'Chromatonema rubrum',
#  'chromatophore',
#  'Chromis',
#  'Chromis limbaughi',
#  'Chromista',
#  'chromite',
#  'Chrysaora',
#  'Chrysaora colorata',
#  'Chrysaora fuscescens',
#  'Chrysaora melanaster',
#  'Chrysaora quinquecirrha',
#  'Chrysogorgia',
#  'Chrysogorgia monticola',
#  'Chrysogorgia pinnata',
#  'Chrysogorgiidae',
#  'Chrysopetalidae',
#  'chubby flashlightfish',
#  'Chuniphyes',
#  'Chuniphyes moserae',
#  'Chuniphyes multidentata',
#  'chute',
#  'Cidaridae',
#  'Cidaroida',
#  'Cidaroidea',
#  'Circeaster',
#  'Circeaster pullus',
#  'Circoporidae',
#  'Cirolanoidea',
#  'Cirrata',
#  'Cirratulidae',
#  'Cirrina',
#  'Cirripedia',
#  'Cirroteuthidae',
#  'Cirroteuthis',
#  'Cirroteuthis muelleri',
#  'Cirrothauma',
#  'Cirrothauma murrayi',
#  'Cirrothauma sp. 1',
#  'Citharichthys',
#  'Citharichthys sordidus',
#  'Cladocera',
#  'Cladopathidae',
#  'Cladorhiza',
#  'Cladorhiza caillieti',
#  'Cladorhiza evae',
#  'Cladorhiza pteron',
#  'Cladorhiza sp. A',
#  'Cladorhiza sp. A-B complex',
#  'Cladorhiza sp. B',
#  'Cladorhizidae',
#  'Clague',
#  'clam',
#  'Clam dumper',
#  'Clam Raceway',
#  'clamshell',
#  'clasper',
#  'clast',
#  'clastic rock',
#  'clathrate',
#  'Clathrate Bucket',
#  'Clausophyes',
#  'Clausophyes moserae',
#  'Clausophyes ovata',
#  'Clausophyes tropica',
#  'Clausophyidae',
#  'Clavelinidae',
#  'Clavularia',
#  'Clavularia grandiflora',
#  'Clavularidae',
#  'claw',
#  'clawed armhook squid',
#  'clay',
#  'claystone',
#  'clear octopus',
#  'clear shimmering vent',
#  'Clidoderma',
#  'Clidoderma asperrimum',
#  'cliff',
#  'Cliidae',
#  'clinopyroxene',
#  'Clio',
#  'Clio cuspidata',
#  'Clio polita',
#  'Clio pyramidata',
#  'Clione',
#  'Clione limacina',
#  'Clionidae',
#  'Clioninae',
#  'Clionoidea',
#  'Cliopsidae',
#  'Cliopsis',
#  'Cliopsis krohnii ',
#  'clonal-plumose anemone',
#  'cloth',
#  'clothing',
#  'Clupea',
#  'Clupea pallasii',
#  'Clupeidae',
#  'Clupeiformes',
#  'Cnemidocarpa',
#  'Cnemidocarpa finmarkiensis',
#  'Cnidaria',
#  'cnidarian',
#  'CO2 Corral',
#  'CO2 Delivery Box',
#  'CO2 Delivery System',
#  'CO2 Exposure Vessel',
#  'CO2 liquid',
#  'CO2 Monitor Box',
#  'cobble',
#  'Coccodiscidae',
#  'cockatoo squid',
#  'cockeyed squid',
#  'cod',
#  'codfish',
#  'codling',
#  'Coelodendridae',
#  'Coelorinchus',
#  'Coelorinchus doryssus',
#  'Coelorinchus scaphopsis',
#  'Coelorinchus spilonotus',
#  'coffinfish',
#  'coiled fecal cast',
#  'colander',
#  'cold seep clam',
#  'Coleodesmium',
#  'Coleographis',
#  'Coleoidea',
#  'collapse pit',
#  'Collodaria',
#  'Collosphaera',
#  'Collosphaerida',
#  'Collozoida',
#  'Collozoum',
#  'Colobonema',
#  'Colobonema sericeum',
#  'Cololabis',
#  'Cololabis saira',
#  'color bars',
#  'color calibration panel',
#  'Colossendeidae',
#  'Colossendeis',
#  'Columbellidae',
#  'column',
#  'columnar jointed outcrop',
#  'Comatulida',
#  'Comatulidina',
#  'comb jelly',
#  'comb plates',
#  'combfish',
#  'Communications Cage',
#  'compass',
#  'Concharidae',
#  'Conchoecissa',
#  'concrete',
#  'Conductivity Probe',
#  'cone medusae',
#  'conger eel',
#  'conglomerate',
#  'Congridae',
#  'Congrinae',
#  'connecting',
#  'connector',
#  'connector cover',
#  'Connor',
#  'Conocara',
#  'Conocara salmonea',
#  'Conocara salmoneum',
#  'consolidated',
#  'contact',
#  'container',
#  'control',
#  'convict fish',
#  'Conway',
#  'Cookeolus',
#  'Cookeolus japonicus',
#  'Coordinated Canyon Experiment Benthic Instrument Node ',
#  'copepod',
#  'Copepoda',
#  'copper rockfish',
#  'coral',
#  'Coralliidae',
#  'Corallimorpharia',
#  'Corallimorphidae',
#  'Corallimorphus',
#  'Corallimorphus denhartogi',
#  'Corallimorphus pilatus',
#  'Corallinaceae',
#  'coralline algae',
#  'Corallium',
#  'Corbitellinae',
#  'Cordagalma',
#  'Core Water Sampler',
#  'corehole',
#  'Corolla',
#  'Corolla spectabilis',
#  'Coronatae',
#  'coronate medusae',
#  'corral',
#  'Cortez damselfish',
#  'Corymorphidae',
#  'Corynactis',
#  'Corynactis californica',
#  'Corynidae',
#  'Corynoidea',
#  'Coryphaenoides',
#  'Coryphaenoides acrolepis',
#  'Coryphaenoides acrolepis-filifer complex',
#  'Coryphaenoides armatus',
#  'Coryphaenoides armatus-leptolepis-yaquinae complex',
#  'Coryphaenoides armatus-yaquinae complex',
#  'Coryphaenoides capito',
#  'Coryphaenoides cinereus',
#  'Coryphaenoides filifer',
#  'Coryphaenoides leptolepis',
#  'Coryphaenoides pectoralis',
#  'Coryphaenoides yaquinae',
#  'Coryphopterus',
#  'Coryphopterus nicholsii',
#  'Cossuridae',
#  'Cottidae',
#  'Cottidae sp. 1',
#  'cow shark',
#  'cowardly anemone',
#  'cowcod',
#  'crab',
#  'crack',
#  'Cranchia',
#  'Cranchia megalops',
#  'Cranchia scabra',
#  'Cranchiidae',
#  'crane',
#  'Crangonidae',
#  'Crangonoidea',
#  'Craseoa',
#  'Craseoa lathetica',
#  'crater pit',
#  'crayfish',
#  'Creseidae',
#  'Creseis',
#  'Creseis virgula',
#  'crested bigscale',
#  'crested oarfish',
#  'crestfish',
#  'crevice',
#  'Cribrinidae',
#  'Crinoidea',
#  'cross jellyfish',
#  'Crossaster',
#  'Crossaster borealis',
#  'Crossota',
#  'Crossota alba',
#  'Crossota millsae',
#  'Crossota pedunculata',
#  'Crossota rufobrunnea',
#  'crown jelly',
#  'Crucibranchaea',
#  'Crucibranchaea macrochira',
#  'crust',
#  'Crustacea',
#  'Cryptonemiales',
#  'Cryptopleura',
#  'Crystallophyes',
#  'Crystallophyes amygdalina',
#  'CTD',
#  'CTD pH Meter Cage',
#  'CTD pH Meter Platform',
#  'Ctenodiscidae',
#  'Ctenodiscus',
#  'Ctenodiscus crispatus',
#  'Ctenodrilidae',
#  'Ctenophora',
#  'Cucumariidae',
#  'Culeolus',
#  'Cunina',
#  'Cuninidae',
#  'cup animal',
#  'curlfin turbot',
#  'current meter',
#  'cushion star',
#  'cuskeel',
#  'cuskpout',
#  'cutter',
#  'Cyanea',
#  'Cyanea capillata',
#  'Cyaneidae',
#  'Cyanobacteria',
#  'Cyclopteridae',
#  'Cyclosalpa',
#  'Cyclosalpa affinis ',
#  'Cyclosalpa bakeri',
#  'Cyclothone',
#  'Cyclothone acclinidens',
#  'Cyclothone pallida',
#  'Cyclothone signata',
#  'Cydippida',
#  'Cyema',
#  'Cyema atrum',
#  'Cyematidae',
#  'cylinder',
#  'Cymbulia',
#  'Cymbuliidae',
#  'Cymodoceaceae',
#  'Cynicoglossus bathybius',
#  'Cynoglossidae',
#  'Cyphocarididae',
#  'Cyphocaris',
#  'Cypridinacea',
#  'Cypridinidae',
#  'Cystechinus',
#  'Cystechinus giganteus',
#  'Cystechinus loveni',
#  'Cystisoma',
#  'Cystisoma fabricii',
#  'Cystisoma magna',
#  'Cystisoma pellucida',
#  'Cystisoma pellucidum',
#  'Cystisomatidae',
#  'Cystocrepis',
#  'Cystocrepis setigera',
#  'Cystodytes',
#  'Cystonectae',
#  'Cystoseira',
#  'Cystoseiraceae',
#  'dab',
#  'dacite',
#  "Dall's Porpoise",
#  'damaged',
#  'damselfish',
#  'Danaphos',
#  'Danaphos oculatus',
#  'Daphne',
#  'darkblotched rockfish',
#  'Dasyatidae',
#  'Dasyatis',
#  'data file',
#  'data logger',
#  'Dawe',
#  'Death-banded snake-eel',
#  'Decapoda',
#  'Decapoda 2',
#  'Decapodiformes',
#  'decorator crab',
#  'deep-sea barnacle',
#  'deep-sea codfish',
#  'deep-sea hatchetfish',
#  'deep-sea hermit crab',
#  'deep-sea shrimp',
#  'deep-sea skate',
#  'deep-sea slickhead',
#  'deep-sea smelt',
#  'deep-sea sole',
#  'deep-sea stalkeye fish',
#  'deep-sea tripod fish',
#  'DeepPIV',
#  'Deepstaria',
#  'Deepstaria enigmatica',
#  'Deepstaria reticulum',
#  'Deepstariinae',
#  'deepwater bigeye',
#  'deepwater eel',
#  'deepwater eelpout',
#  'deepwater slipskin',
#  'defecating',
#  'Deimatidae',
#  'DEIMOS',
#  'Deiopea',
#  'Deiopea kaloktenota',
#  'Deiopeidae',
#  'Delectopecten',
#  'Delesseriaceae',
#  'Delphinidae',
#  'Demospongiae',
#  'Dendrobranchiata',
#  'Dendrochirotida',
#  'Dendronotida',
#  'Dendronotidae',
#  'Dendronotus',
#  'Dendronotus patricki',
#  'Dendropathes',
#  'Dendrophylliidae',
#  'dense tube feet impressions',
#  'deposit',
#  'depression',
#  'Derbesia',
#  'Derbesia marina',
#  'Derbesiaceae',
#  'Derepodichthys',
#  'Derepodichthys alepidotus',
#  'Derichthyidae',
#  'Dermasterias',
#  'Dermasterias imbricata',
#  'Desmarestia',
#  'Desmarestiaceae',
#  'Desmarestiales',
#  'Desmodema',
#  'Desmodema lorum',
#  'Desmophyes',
#  'Desmophyes annectens',
#  'Desmophyes haematogaster',
#  'Desmophyllum',
#  'Desmophyllum dianthus',
#  'Desmopteridae',
#  'Desmopterus',
#  'Desmopterus papilio',
#  'detrital',
#  'detrital aggregate',
#  'detritus',
#  'Detritus Sampler',
#  'Dexiarchia',
#  'diabase',
#  'diamond turbot',
#  'diaphanous hatchetfish',
#  'Diaphus',
#  'Diaphus anderseni',
#  'Diaphus pacificus',
#  'Diaphus theta',
#  'Diaphus trachops',
#  'diatom',
#  'diatomaceous rock',
#  'Dibranchus',
#  'Dibranchus hystrix',
#  'Dibranchus sp. A',
#  'Dibranchus spinosus',
#  'Didemnidae',
#  'Didemnum',
#  'dike',
#  'diogenes lanternfish',
#  'Diogenichthys',
#  'Diogenichthys atlanticus',
#  'Diogenichthys laternatus',
#  'Diogenidae',
#  'Diomedea',
#  'Diomedeidae',
#  'diorite',
#  'Diphyidae',
#  'Diphyinae',
#  'Dipleurosoma',
#  'Dipleurosoma typicum',
#  'Dipleurosomatidae',
#  'Diplophos',
#  'Diplophos pacificus',
#  'Diplosoma',
#  'Dipsacaster',
#  'disconnecting',
#  'disk',
#  'Dissolution Ball',
#  'Distichoptilum',
#  'Distichoptilum gracile',
#  'Ditropichthys',
#  'Ditropichthys storeri',
#  'Ditrupa',
#  'diving',
#  'Doc Ricketts',
#  'dock',
#  'Docosaccus',
#  'Docosaccus maculatus',
#  'Dodecaceria',
#  'Dofleinia',
#  'dogtooth lampfish',
#  'Doliolenetta',
#  'Dolioletta',
#  'Doliolida',
#  'Doliolida 2',
#  'Doliolida contains tail',
#  'Doliolidae',
#  'Doliolinetta',
#  'Doliolula',
#  'Doliolula equus',
#  'Doliolum',
#  'Doliolunidae',
#  'Doliopsidae',
#  'Doliopsidina',
#  'dollar hatchet fish',
#  'dolomite',
#  'Dolopichthys',
#  'Dolopichthys longicornis',
#  'dolphin',
#  'dongo',
#  'donk',
#  'Doridacea',
#  'Doridoidea',
#  'Dorvilleidae',
#  'Doryteuthis',
#  'Doryteuthis opalescens',
#  'Dosidicus',
#  'Dosidicus gigas',
#  'double-dot-medusa',
#  'dover sole',
#  'dragonfish',
#  'drainback',
#  'drained lobe',
#  'drained pillow',
#  'drawer',
#  'dreamer',
#  'driftfish',
#  'drifting',
#  'drill',
#  'drill bit',
#  'Dromalia',
#  'Dromalia alexandri',
#  'drop weight',
#  'dropstone',
#  'Dryodora',
#  'Dryodora glandiformis',
#  'Dryodoridae',
#  'duckbill barracudina',
#  'duckbill eel',
#  'Dungeness crab',
#  'dunite',
#  'dusky hatchetfish',
#  'dusky sculpin',
#  'dustpan',
#  'Dye Injector',
#  'Dytaster',
#  'Dytaster gilberti',
#  'Dytaster sp. 1',
#  'ear',
#  'eared seal',
#  'Earleria',
#  'Earleria corachloeae',
#  'Earleria purpurea',
#  'earless seal',
#  'East Pacific codlet',
#  'Eastern Pacific black ghostshark',
#  'Eastern Pacific bobtail squid',
#  'Echinacea',
#  'Echinaster',
#  'Echinasteridae',
#  'Echinidea',
#  'Echinocrepis',
#  'Echinocrepis rostrata',
#  'Echinocrepis setigera',
#  'echinoderm',
#  'Echinodermata',
#  'echinoid',
#  'Echinoida',
#  'Echinoidea',
#  'Echinorhinidae',
#  'Echinorhinus',
#  'Echinorhinus cookei',
#  'Echinothuriidae',
#  'Echinothurioida',
#  'Echiura',
#  'echiuran worm',
#  'Echiurida',
#  'Echiuroidea',
#  'Eclysippe',
#  'Ectenagena',
#  'Ectenagena elongata',
#  'Ectenagena extenta ',
#  'ectoproct',
#  'ectoprocta',
#  'Eddy Correlation Sensor',
#  'Eddy Flux Package',
#  'Edwardsia',
#  'Edwardsiidae',
#  'Edwardsioidea',
#  'eel',
#  'eel grass',
#  'eelpout',
#  'eggcase',
#  'eggs',
#  'eggyolk jelly',
#  'Egregia',
#  'Egregia menziesii',
#  'Eirenidae',
#  'Eisenia',
#  'Eisenia arborea',
#  'EITS',
#  'Eknomoliparis',
#  'Eknomoliparis chirichignoae',
#  'Elasipodida',
#  'Elasmobranchii',
#  'electric ray',
#  'Electrona',
#  'Electrona risso',
#  'elephant seal',
#  'elevator',
#  'Elpidia',
#  'Elpidia sp. A',
#  'Elpidiidae',
#  'Embassichthys',
#  'Embassichthys bathybius',
#  'Embiotocidae',
#  'Emergence Trap',
#  'enclosure',
#  'end effector',
#  'Endocoelantheae',
#  'Endomyaria',
#  'English sole',
#  'Engraulidae',
#  'Engraulis',
#  'Engraulis mordax',
#  'Enhydra',
#  'Enhydra lutris',
#  'Enopla',
#  'Enoploteuthidae',
#  'Enteroctopus',
#  'Enteroctopus dofleini',
#  'Enterogona ',
#  'enteropneust hairpin fecal cast',
#  'enteropneust mixed-type fecal cast',
#  'enteropneust spiral',
#  'enteropneust spiral fecal cast',
#  'Enteropneusta',
#  'Enthemonae',
#  'Entosphenus',
#  'Entosphenus tridentatus',
#  'Environmental Sample Processor',
#  'Enypniastes',
#  'Eopsetta',
#  'Eopsetta exilis',
#  'Eopsetta jordani',
#  'epidote',
#  'Epinephelinae',
#  'Epinephelus',
#  'Epinephelus labriformis',
#  'Epizoanthidae',
#  'Epizoanthus ',
#  'Epizoanthus stellaris',
#  'Eptatretinae ',
#  'Eptatretus',
#  'Eptatretus deani',
#  'Eptatretus stoutii',
#  'equipment',
#  'Erenna',
#  'Erenna cornuta',
#  'Erenna insidiator',
#  'Erenna laciniata',
#  'Erenna richardi',
#  'Erenna sirena',
#  'Erennidae',
#  'eroded surface',
#  'Errantia',
#  'erratic stone',
#  'Errex zachirus',
#  'Eryoneicus larvae',
#  'Eryonoidea',
#  'Escarpia',
#  'Escarpia spicata',
#  'escarpment',
#  'Eschrichtiidae',
#  'Eschrichtius',
#  'Eschrichtius robustus',
#  'ESP',
#  'Eualus',
#  'Eualus gaimardii',
#  'Eualus gaimardii belcheri',
#  'Eualus macrophthalmus',
#  'Eubacteria',
#  'Eucarida',
#  'Euchaeta',
#  'Euchaetidae',
#  'Euchirella',
#  'Euchirella bitumida',
#  'Euchone',
#  'Eucryphycus',
#  'Eucryphycus californicus',
#  'Euctenidiacea ',
#  'Euechinoidea',
#  'Eukaryota',
#  'Eukrohnia',
#  'Eukrohnia bathyantarctica',
#  'Eukrohnia fowleri',
#  'Eukrohnia hamata',
#  'Eukrohniidae',
#  'Eulecithophora ',
#  'Eulepethidae',
#  'Eulimidae',
#  'Eulimoidea',
#  'Eumalacostraca',
#  'Eumedusa',
#  'Eunicida',
#  'Eunicidae',
#  'Euphausia',
#  'Euphausia 2',
#  'Euphausia individual',
#  'Euphausia krill swarm',
#  'Euphausia pacifica',
#  'Euphausiacea',
#  'Euphausiidae',
#  'euphotic zone',
#  'Euphysa',
#  'Euphysa flammea',
#  'Euphysa japonica',
#  'Euphysetta',
#  'Euphysora',
#  'Euphysora gigantea',
#  'Euphysora valdiviae',
#  'Euplectella',
#  'Euplectellidae',
#  'Euplectellinae',
#  'Euplexaura',
#  'Euplokamidae',
#  'Euplokamis',
#  'Euplokamis dunlapae',
#  'Euretidae',
#  'Eurhamphaea',
#  'Eurhamphaea vexilligera',
#  'Eurhamphaeidae',
#  'Eurphrosinidae',
#  'Euryalida',
#  'Euryalina',
#  'Eurycope',
#  'Eurycopinae',
#  'Eurypharyngidae',
#  'Eurypharynx',
#  'Eurypharynx pelecanoides',
#  'Eusergestes',
#  'Eusergestes similis',
#  'Eusmiliidae',
#  'Euspira lewisii',
#  'Euthecosomata',
#  'Eutima',
#  'Eutonina',
#  'Eutonina indicans',
#  'Evermannella',
#  'Evermannella ahlstromi',
#  'Evermannellidae',
#  'Evoplosoma',
#  'Evoplosoma claguei',
#  'Evoplosoma voratus',
#  'Exclusion Cage',
#  'excreting',
#  'Exilia',
#  'Exocoelactinidae',
#  'Exocoelactis',
#  'Extensometer',
#  'external battery pack',
#  'extrusive',
#  'eye',
#  'Eye-in-the-Sea',
#  'F-8 Crusader wreckage',
#  'fabric',
#  'Facciolella',
#  'fangtooth',
#  'fangtooth fish',
#  'fantail sole',
#  'Fariometra',
#  'Fariometra parvula',
#  'Farrea',
#  'Farrea occa',
#  'Farrea sp. A',
#  'Farrea truncata',
#  'Farrea truncata complex',
#  'Farreidae',
#  'fathead',
#  'Fauchea',
#  'Fauchea laciniata',
#  'fault',
#  'fault scarp',
#  'Fauveliopsidae',
#  'feather star',
#  'feather-foot spider isopod',
#  'featherboa kelp',
#  'fecal cast',
#  'fecal material',
#  'fecal mound',
#  'fecal pellet',
#  'Fecampiid eggcase',
#  'Fecampiida',
#  'feeding trace',
#  'feldspar',
#  'Ferosagitta',
#  'Ferosagitta ferox',
#  'Ferosagitta robusta',
#  'field of view',
#  'field of view 24',
#  'field of view 30',
#  'field of view 36',
#  'field of view 39',
#  'filament',
#  'filamented grenadier',
#  'filamented rattail',
#  'filetail catshark',
#  'Filifera',
#  'Filosa',
#  'filter',
#  'fin',
#  'fin ray',
#  'fine-spined skate',
#  'fire squid',
#  'firefish',
#  'Firoloida',
#  'fish trap',
#  'fishing',
#  'fishing float',
#  'fissure',
#  'Fissurellacea',
#  'Fissurellidae',
#  'Fissurelloidea',
#  'flabby whalefish',
#  'Flabellidae',
#  'Flabellifera',
#  'Flabelligeridae',
#  'flag cabrilla',
#  'flag rockfish',
#  'flange',
#  'flatfish',
#  'flathead sole',
#  'flatworm',
#  'float',
#  'Florometra',
#  'Florometra serratissima',
#  'Flota',
#  'Flota flabelligera',
#  'Flota vitjasi',
#  'Flotidae',
#  'flotsamfish',
#  'flounder',
#  'flow meter',
#  'flower animal',
#  'Flustrina',
#  'FOCE',
#  'Foersteria',
#  'Foersteria purpurea',
#  'fold',
#  'folded flow',
#  'foot',
#  'footprint',
#  'foram',
#  'foram settlement cage',
#  'Foraminifera',
#  'Foraminiferida',
#  'Forcipulatacea',
#  'Forcipulatida',
#  'Forskalia',
#  'Forskalia edwardsi',
#  'Forskalia formosa',
#  'Forskalia tholoides',
#  'Forskaliidae',
#  'fossil',
#  'fracture',
#  'fragile urchin',
#  'fragmental',
#  'Free Ocean CO2 Experiment',
#  'free-swimming',
#  'Frenulata',
#  'Freyellaster',
#  'Freyellaster fecundus',
#  'Freyellidae',
#  'fried egg jelly',
#  'Frillagalma',
#  'Frillagalma vityazi',
#  'fringed sculpin',
#  'Fritillaria',
#  'Fritillariidae',
#  'Fritillariinae',
#  'frogmouthed sculpin',
#  'fry scoop',
#  'Fryeella',
#  'Fryeella gardneri',
#  'Fucaceae',
#  'Fucales',
#  'Fucus',
#  'Fulgorariinae',
#  'Fungi',
#  'Fungiacyathus',
#  'Fungiacyathus marenzelleri',
#  'Fungiidae',
#  'Funiculina',
#  'Funiculina-Halipteris complex',
#  'Funiculinidae ',
#  'gabbro',
#  'Gadella',
#  'Gadella jordani',
#  'Gadidae',
#  'Gadiformes',
#  'Gadomus',
#  'Gadomus melanopterus',
#  'Gadus',
#  'Galathea',
#  'Galatheidae',
#  'Galatheoidea',
#  'galena',
#  'Galiteuthis',
#  'Galiteuthis pacifica',
#  'Galiteuthis phyllura',
#  'gametes',
#  'gammarid amphipod',
#  'Gammaridea',
#  'gas',
#  'Gas  Sampler I',
#  'gas hydrate',
#  'Gas Sampler I',
#  'Gas Sampler II',
#  'gas vent',
#  'Gas-tight Water Sampler',
#  'gastropod',
#  'Gastropoda',
#  'Gastropoda sp. 2',
#  'Gastropoda sp. 3',
#  'Gastroptychus',
#  'Gastroptychus perarmatus',
#  'gastrozooid',
#  'gauge',
#  'Gaussia',
#  'Gaussia princeps',
#  'Gennadas',
#  'geological feature',
#  'geological morphology',
#  'Geosense',
#  'Gephyrocrinus',
#  'Gephyrocrinus messingi',
#  'Gersemia',
#  'Gersemia juliepackardae',
#  'Geryonia',
#  'Geryonia proboscidalis',
#  'Geryoniidae',
#  'ghost shrimp',
#  'ghost tail',
#  'ghostly grenadier',
#  'giant cuskeel',
#  'giant damselfish',
#  'giant grenadier',
#  'giant kelp',
#  'giant lampfish',
#  'giant larvacean',
#  'giant ostracod',
#  'Gigantactinidae',
#  'Gigantactis',
#  'Gigantactis gargantua',
#  'Gigantactis vanhoeffeni',
#  'Gigantocypris',
#  'Gigantocypris agassizii',
#  'Gigantocypris dracontovalis',
#  'Gigantura',
#  'Gigantura indica',
#  'Giganturidae',
#  'Gigartina',
#  'Gigartinaceae',
#  'Gigartinales',
#  'gills',
#  'girdle ctenophore',
#  'GIS map',
#  'glass',
#  'glass inclusion',
#  'glass shrimp',
#  'Glass Suction Sampler',
#  'Gleba',
#  'Gleba cordata',
#  'Globigerinidae',
#  'Globigerinoidea',
#  'Glossocephalus',
#  'Glossodiea',
#  'Glossoidea',
#  'Glyceridae',
#  'Glyphocragon',
#  'Glyphocrangon vicaria',
#  'Glyphocrangonidae',
#  'Glyptocephalus',
#  'Glyptocephalus zachirus',
#  'Gnathophausia',
#  'Gnathophausia ingens',
#  'Gnathophis',
#  'Gnathophis cinctus',
#  'Gnathostomata',
#  'gneiss',
#  'Go-Flo Bottle',
#  'Gobiidae',
#  'Gobiinae',
#  'Gobionellinae',
#  'goblinfish',
#  'goby',
#  'golden-eye mysid',
#  'Goldspotted sand bass',
#  'golf ball',
#  'gonads',
#  'Gonatidae',
#  'Gonatopsis',
#  'Gonatopsis borealis',
#  'Gonatopsis octopedatus',
#  'Gonatus',
#  'Gonatus berryi',
#  'Gonatus onyx',
#  'Gonatus pyros',
#  'Goniadidae',
#  'Goniasteridae',
#  'Goniopectinidae',
#  'Gonostomatidae',
#  'goosefish',
#  'gopher rockfish',
#  'Gorgonacea',
#  'Gorgoniidae',
#  'Gorgonocephalidae',
#  'Gorgonocephalus',
#  'Gorgonocephalus eucnemis',
#  'Gorgonocephalus japonicus',
#  'GPS',
#  'grab respirometer',
#  'grabbing',
#  'graduated cylinder',
#  'Graneledone',
#  'Graneledone boreopacifica',
#  'Graneledone pacifica',
#  'Graneledoninae',
#  'granite',
#  'granodiorite',
#  'gravel',
#  'gray frame',
#  'gray starnose poacher',
#  'gray starsnout',
#  'gray whale',
#  'graywacke',
#  'great white shark',
#  'green algae',
#  'green bomber',
#  'greenblotched rockfish',
#  'greenling',
#  'greenspotted rockfish',
#  'greenstone',
#  'greenstriped rockfish',
#  'grenadier',
#  'grey whale',
#  'grid',
#  'Grimalditeuthis',
#  'Grimalditeuthis bonplandi ',
#  'Grimpoteuthis',
#  'Grimpoteuthis bathynectes',
#  'Grimpoteuthis cf. bathynectes',
#  'Grimpoteuthis sp. 1',
#  'Grimpoteuthis sp. 4',
#  'Grimpoteuthis sp. 5',
#  'Grimpoteuthis tuftsi',
#  'groove',
#  'groove on marine organism',
#  'grooved tanner crab',
#  'grouper',
#  'grunt',
#  'gully',
#  'gulper',
#  'gulper eel',
#  'Gulper hydraulic',
#  'Gulper standalone',
#  'Gulper – hydraulic',
#  'Gulper–standalone',
#  'gumdrop',
#  'Guralp seismometer',
#  'gut',
#  'Gymnelinae',
#  'Gymnolaemata',
#  'Gymnoplea',
#  'Gymnopraia',
#  'Gymnopraia lapislazula',
#  'Gymnosomata',
#  'Gymnothorax',
#  'Gymnothorax berndti',
#  'gypsum',
#  'hadal',
#  'Haddock',
#  'Hadromerida',
#  'Haeckelia',
#  'Haeckelia beehleri',
#  'Haeckelia rubra',
#  'Haeckeliidae',
#  'Haemulidae',
#  'Haemulinae',
#  'hagfish',
#  'hair seal',
#  'hake',
#  'halfbanded rockfish',
#  'halibut',
#  'Halicreas',
#  'Halicreas minimum',
#  'Halicreatidae',
#  'Haliotidae',
#  'Haliotis',
#  'Haliotis rufescens',
#  'Haliotoidea',
#  'Haliphron',
#  'Haliphron atlanticus',
#  'Halipteridae',
#  'Halipteris',
#  'Halipteris californica',
#  'Haliscera',
#  'Haliscera bigelowi',
#  'Haliscera conica',
#  'Halistemma',
#  'Halistemma rubrum',
#  'Halitrephes',
#  'Halitrephes maasi',
#  'Halocyprida',
#  'Halocyprididae',
#  'halosaur',
#  'Halosauridae',
#  'hammerhead larvacean',
#  'hanging',
#  'harbor porpoise',
#  'harbor seal',
#  'hardnose skates',
#  'Harmothoe',
#  'Harosa',
#  'harp sponge',
#  'Harrimaniidae',
#  'Harriotta',
#  'Harriotta raleighana',
#  'Hartmaniellidae',
#  'Hastigerinella',
#  'Hastigerinella digitata',
#  'Hastigerininae',
#  'Hastigerinopsis digitiformans',
#  'hatchetfish',
#  'Hawaiian flying squid',
#  'hawaiite',
#  'head',
#  'headfish',
#  'heart urchin',
#  'Heat Flow Probe',
#  'Helicocranchia',
#  'Helicosalpa',
#  'Helicosalpa virgula',
#  'Heliometrinae',
#  'Hemanthias',
#  'Hemanthias peruanus',
#  'hematite',
#  'Hemichordata',
#  'Henactis',
#  'Henactis seepala',
#  'Henricia',
#  'Henricia cf. asthenactis',
#  'Henricia sp. 1',
#  'hermit crab',
#  'herring',
#  'herring smelt',
#  'Hesionidae',
#  'Heterarthrandria',
#  'Heterobranchia',
#  'Heterochone',
#  'Heterochone calyx',
#  'Heterodonta',
#  'Heterokonta',
#  'Heterokrohnia',
#  'Heterokrohnia involucrum',
#  'Heterokrohniidae',
#  'Heteropathes',
#  'heteropod',
#  'Heteropoda',
#  'Heteropolypus',
#  'Heteropolypus ritteri',
#  'Heterotiara',
#  'Heterotiara minor',
#  'Heterozonias',
#  'Heterozonias alternatus',
#  'Hexacorallia',
#  'Hexactinella',
#  'Hexactinellida',
#  'Hexactinellida sp. 1',
#  'Hexactinellida sp. 2',
#  'Hexactinellida sp. 3',
#  'Hexactinellida sp. 4',
#  'Hexactinosida',
#  'Hexagrammidae',
#  'Hexagramminae',
#  'Hexagrammos',
#  'Hexagrammos decagrammus',
#  'Hexagrammos stelleri',
#  'hexanchias',
#  'Hexanchidae',
#  'Hexanchiformes',
#  'Hexanchus',
#  'Hexanchus griseus',
#  'hexancus',
#  'Hexapathinae',
#  'Hexasterophora',
#  'Hexatrygon',
#  'Hexatrygon bickelli',
#  'Hexatrygonidae',
#  'hide',
#  'Hierops crockeri',
#  'high magnesium calcite',
#  'High Temperature Probe',
#  'High Temperature Recorder',
#  'highfin dragonfish',
#  'highfin lizardfish',
#  'highsnout bigscale',
#  'Hippasteria',
#  'Hippasteria californica',
#  'Hippasteria lepidonotus',
#  'Hippasteria phrygiana',
#  'Hippasteria spinosa',
#  'Hippasteria tiburoni',
#  'Hippasterinae',
#  'Hippoglossina',
#  'Hippoglossina stomata',
#  'Hippoglossoides',
#  'Hippoglossoides elassodon',
#  'Hippoglossus',
#  'Hippoglossus stenolepis',
#  'Hippolytidae',
#  'Hippopodiidae',
#  'Hippopodius',
#  'Hippopodius hippopus',
#  'Hirudinea',
#  'Histioteuthidae',
#  'Histioteuthis',
#  'Histioteuthis heteropsis',
#  'hobo',
#  'Holacanthus',
#  'Holacanthus passer',
#  'Holasterina',
#  'Holasteroida',
#  'Holaxonia',
#  'holdfast',
#  'hole',
#  'hole pair burrow',
#  'Hollardia',
#  'Holocephali',
#  'Holothuria',
#  'Holothuria zacae',
#  'holothurian',
#  'Holothuriidae',
#  'Holothuroidea',
#  'Holothuroidea sp. 3',
#  'Holothuroidea sp. 4',
#  'Holothuroidea sp. 5',
#  'Holothuroidea sp. 6',
#  'Holothuroidea sp. 7',
#  'Homerpro',
#  'honeycomb rockfish',
#  'Hopcroft, Russ',
#  'Hoplocarida',
#  'Hoplonemertea',
#  'Hopper with Glass Marbles',
#  'Hormathiidae',
#  'Hormathiidae sp. 1',
#  'Hormiphora',
#  'Hormiphora californensis',
#  'hornblende',
#  'hornito',
#  'horny coral',
#  'hornyhead turbot',
#  'hose',
#  'housing',
#  'Howella',
#  'howella',
#  'Howella brodiei',
#  'human',
#  'Humboldt squid',
#  'humpback whale',
#  'hundred-fathom codling',
#  'Hunt',
#  'Hyalinoeciinae',
#  'hyaloclastite',
#  'Hyalocylis',
#  'Hyalocylis striata',
#  'Hyalonema',
#  'Hyalonema bianchoratum',
#  'Hyalonema populiferum',
#  'Hyalonema sp. 1',
#  'Hyalonematidae',
#  'Hydractinia',
#  'Hydractiniidae',
#  'hydralike animal',
#  'Hydrasterias',
#  'Hydrate Bucket I',
#  'Hydrate Bucket II',
#  'Hydrate Cylinder',
#  'Hydrate Experiment',
#  'Hydrate Exposure Vessel I',
#  'Hydrate Exposure Vessel II',
#  'Hydrate Observatory I',
#  'Hydrate Observatory II',
#  'Hydrate Pressure Vessel',
#  'Hydrate Synthesis Chamber',
#  'Hydraulic Push Corer',
#  'hydrocarbon',
#  'hydrogen sulfide',
#  'hydroid',
#  'Hydroidolina',
#  'Hydrolagus',
#  'Hydrolagus colliei',
#  'Hydrolagus melanophasma',
#  'Hydrolagus trolli',
#  'Hydromedusae',
#  'hydrophone',
#  'hydrothermal alteration',
#  'hydrothermal clay',
#  'hydrothermal crust',
#  'hydrothermal sediment and bacterial floc mixture',
#  'hydrothermal vent',
#  'hydrothermal vent limpets',
#  'Hydrozoa',
#  'hydrozoan',
#  'Hymenaster',
#  'Hymenaster koehleri',
#  'Hymenodiscus',
#  'Hymenodora',
#  'Hymenodora frontalis',
#  'Hymenopenaeus',
#  'Hymenopenaeus doris',
#  'Hyocrinida',
#  'Hyocrinidae',
#  'Hyocrinus',
#  'hyperiid amphipod',
#  'Hyperiidae',
#  'Hyperiidea',
#  'Hypsopsetta guttulata',
#  'Iasis',
#  'Iasis zonaria',
#  'Icelidae',
#  'Icelinus',
#  'Icelinus burchami',
#  'Icelinus filamentosus',
#  'Icelinus fimbriatus',
#  'Icelinus oculatus',
#  'Icelinus quadriseriatus',
#  'Icelinus tenuis',
#  'icelinus-tenuis',
#  'Ichthyotomidae',
#  'Icichthys',
#  'Icichthys lockingtoni',
#  'Icosteidae',
#  'Icosteus',
#  'Icosteus aenigmaticus',
#  'Idas',
#  'Idas washingtonius',
#  'Idiacanthinae',
#  'Idiacanthus',
#  'Idiacanthus antrostomus',
#  'Idiacanthus fasciola',
#  'igneous rock',
#  'iherzolite',
#  'ilmenite',
#  'Impact Glass Sampler',
#  'In Situ Ultraviolet Spectrophotometer',
#  'Inachidae',
#  'inactive',
#  'Incirrata',
#  'Incirrina',
#  'incubation frame',
#  'Inductive power transfer tool',
#  'ink',
#  'Ink Dispenser',
#  'ink sac',
#  'inking',
#  'inner filter',
#  'interpretation',
#  'interradial arc',
#  'intrusive',
#  'Iosactiidae',
#  'Iosactinidae',
#  'Iosactis',
#  'Iosactis vagabunda',
#  'Iospilidae',
#  'Ipnopidae',
#  'Iridogorgia',
#  'iris',
#  'iron oxide',
#  'irregular-shaped scar',
#  'Irregularia',
#  'Ischnomesidae',
#  'Isidella',
#  'Isidella tentaculum',
#  'Isididae',
#  'isopod',
#  'Isopoda',
#  'Isopsetta',
#  'Isosicyonis',
#  'Isostichopus',
#  'Isostichopus fuscus',
#  'ISUS',
#  'ISUS Lander',
#  'Iulopididae',
#  'Iulopis',
#  'Iwamoto, Tomio',
#  'j-posing',
#  'jack',
#  'jack mackerel',
#  'Jacobsen Stout',
#  'Janetogalathea',
#  'Janiroidea',
#  'Japetella',
#  'Japetella diaphana',
#  'Javania',
#  'Javania cailleti',
#  'jawless fish',
#  'jelly, unidentified from Hydrozoa or Scyphozoa',
#  'jellyfish',
#  'Johnrandallia',
#  'Johnrandallia nigrirostris',
#  'joint',
#  "Julie Packard's Treasure Coral",
#  'Kadosactis',
#  'Kali',
#  'Kali indica',
#  'Kali kerberti',
#  'Kali normani',
#  'kelp',
#  'kelp greenling',
#  'kelp holdfast',
#  'Kephyes',
#  'Kephyes ovata',
#  'Keratoisis',
#  'keyhole limpet',
#  'king angelfish',
#  'king crab',
#  'king of the salmon',
#  'Kiyohimea',
#  'Kiyohimea usagi',
#  'Kiyohimeidae',
#  'knife',
#  'knotted cast',
#  'knotted fecal cast',
#  'Kophobelemnidae',
#  'Kophobelemnon',
#  'Kophobelemnon biflorum',
#  'Kophobelemnon sp. 1',
#  'Korethrasteridae',
#  'Kowalevskia',
#  'Kowalevskiidae',
#  'Kraft raptor',
#  'krill',
#  'Krill molt',
#  'krill swarm',
#  'L Cheapo',
#  'label',
#  'Labridae',
#  'Labrisomidae',
#  'Lacydoniidae',
#  'Laetmogone',
#  'Laetmogone wyvillethomsoni',
#  'Laetmogonidae',
#  'Laetmonice',
#  'lag deposit',
#  'Lagenorhynchus',
#  'Lagenorhynchus obliquidens',
#  'Lagrangian sediment trap',
#  'Lamellibrachia',
#  'Laminaria',
#  'Laminariaceae',
#  'Laminariales',
#  'Lamna',
#  'Lamna ditropis',
#  'Lamnidae',
#  'Lamniformes',
#  'lamp shell',
#  'Lampadena',
#  'Lampadena urophaos urophaos',
#  'Lampanyctus',
#  'Lampanyctus regalis',
#  'Lampanyctus ritteri',
#  'Lampea',
#  'Lampea pancerina',
#  'Lampeidae',
#  'Lampetra tridentata',
#  'Lampocteis',
#  'Lampocteis cruentiventer',
#  'Lampoctena',
#  'Lampoctenidae',
#  'lamprey',
#  'Lampridae',
#  'Lampriformes',
#  'lance squid',
#  'Lanceola',
#  'Lanceolidae',
#  'Lanceoloidea',
#  'lancetfish',
#  'lanternfish',
#  'Laodiceidae',
#  'Laqueidae',
#  'Laqueus',
#  'Laqueus californianus',
#  'large-tooth flounder',
#  'Larvacea',
#  'larvacean',
#  'larvacean house',
#  'larval flatfish',
#  'Larval Incubation Chamber',
#  'Larval Sampler',
#  'Larval Tray',
#  'Laser Raman',
#  'lasers',
#  'last name',
#  'latch',
#  'launch',
#  'lava channel',
#  'lava flow',
#  'lava form',
#  'lava pillar',
#  'lava pond',
#  'lava ring',
#  'lava tube',
#  'lava whorl',
#  'lavacicle',
#  'Leachia',
#  'Leachia danae',
#  'lead line',
#  'leather',
#  'leather star',
#  'Lebensspuren',
#  'ledge',
#  'left handed hermit crab',
#  'lefteyed flounder',
#  'leg',
#  'Lensia',
#  'Lensia achilles',
#  'Lensia baryi',
#  'Lensia conoidea',
#  'Lensia havock',
#  'Lensia hostile',
#  'Lensia hotspur',
#  'Lensia multicristata',
#  'Lepadidae',
#  'Lepadidoidea',
#  'Lepadomorpha',
#  'Lepas',
#  'Lepetodrilidae',
#  'Lepetodriloidea',
#  'Lepetodrilus',
#  'Lepetodrilus fucensis',
#  'Lepetodrilus gordensis',
#  'Lepidion',
#  'Lepidisis',
#  'Lepidogobius',
#  'Lepidogobius lepidus',
#  'Lepidopsetta',
#  'Lepidopsetta bilineata',
#  'Lepralielloidea',
#  'Leptasterias',
#  'Leptocephalus',
# ...
#  'seismonument',
#  'Self Triggering Event Detector',
#  'Semaeostomae',
#  'Semaeostomeae',
#  'Sepiolida',
#  'Sepiolidae',
#  'sequence',
#  'Sergestes',
#  'Sergestes similis',
#  'Sergestid molt',
#  'Sergestidae',
#  'Sergestoidea',
#  'Sergia',
#  'Sergia phorca',
#  'Seriola',
#  'Seriola rivoliana',
#  'Serpulidae',
#  'Serpulorbis',
#  'Serpulorbis squamiger',
#  'Serranidae',
#  'Serraninae',
#  'Serranus',
#  'Serranus psittacinus',
#  'Serrivomer',
#  'Serrivomer sector',
#  'Serrivomeridae',
#  'SES',
#  'sessile tunicate',
#  'Sessiliflorae',
#  'seta',
#  'settlement trap',
#  'sevengill shark',
#  'shackle',
#  'shadow',
#  'shale',
#  'shallow wide depression track',
#  'sharpchin rockfish',
#  'sheet flow',
#  'shelf',
#  'shell',
#  'shell fragment',
#  'shell hash',
#  'shelled pteropod',
#  'shimmering',
#  'shining tubeshoulder',
#  'shiny loosejaw',
#  'ship',
#  'ship container',
#  'ship wreckage',
#  'ship wreckage-2',
#  'shirt',
#  'shoe',
#  'shoe-2',
#  'shore worm',
#  'shortbelly rockfish',
#  'shortfin pearleye',
#  'shortnose swallower',
#  'shortnose witch eel',
#  'shortnosed chimaera',
#  'shortraker rockfish',
#  'shortspine combfish',
#  'shortspine thornyhead',
#  'shoulderspot grenadier',
#  'showy bristlemouth',
#  'shrimp',
#  'Sibogagorgia',
#  'Sibogagorgia cauliflora',
#  'Sibogaster',
#  'Sibogaster nieseni ',
#  'Sibogita',
#  'Siboglinidae',
#  'Sicyonis',
#  'Sicyonis careyi',
#  'Sicyonis sp. 1',
#  'Sicyopus',
#  'Sicyopus commensalis',
#  'Sigalionidae',
#  'Sige',
#  'Sige brunnea',
#  'silica',
#  'silicate',
#  'silicic volcanic',
#  'siltstone',
#  'silvergray rockfish',
#  'silvery hatchet fish',
#  'silvery topsnail',
#  'single groove track',
#  'single hole burrow',
#  'single-dot-medusa',
#  'sinker',
#  'Sinking Ball',
#  'Sinking Chamber',
#  'siphon',
#  'Siphonophora',
#  'Siphonophorae',
#  'siphonophore',
#  'Siphonosphaera',
#  'Sipuncula',
#  'sipunculan worm',
#  'sit camera',
#  'site marker',
#  'sixgill shark',
#  'sizing',
#  'skate',
#  'skeleton',
#  'skeleton shrimp',
#  'sky hook',
#  'skylight',
#  'slate',
#  'slender barracudina',
#  'slender blacksmelt',
#  'slender hatchetfish',
#  'slender sole',
#  'slender-sea-pen',
#  'slickenside',
#  'slickhead fish',
#  'slide',
#  'slope',
#  'slope break',
#  'slump',
#  'slump scarp',
#  'small perforated disks',
#  'smalldisk snailfish',
#  'smalleye barracudina',
#  'smalleye snipe eel',
#  'smalleye squaretail',
#  'smectite',
#  'smelt',
#  'Sminthea',
#  'Smithsonius',
#  'Smithsonius dorothea',
#  'smooth cast',
#  'smooth fecal cast',
#  'smooth grenadier',
#  'smoothhead fish',
#  'snaggletooth',
#  'snail',
#  'snailfish',
#  'snake prickleback',
#  'snakehead eelpout',
#  'snipe eel',
#  'snubnose blacksmelt',
#  'snubnose eelpout',
#  'soft coral',
#  'softball',
#  'softnose skates',
#  'Solaster',
#  'Solaster borealis',
#  'Solaster endeca',
#  'Solaster hypothrissus',
#  'Solasteridae',
#  'sole',
#  'Solemya',
#  'Solemyacea',
#  'Solemyidae',
#  'Solemyoida',
#  'Solenoceridae',
#  'Solenosphaera',
#  'Solidosagitta',
#  'Solidosagitta zetesios',
#  'Solmaris',
#  'Solmarisidae',
#  'Solmissus',
#  'Solmissus incisa',
#  'Solmissus incisus',
#  'Solmissus marshalli',
#  'Solmundella',
#  'Solmundella bitentaculata',
#  'somersaulting',
#  'somersaulting-spider-isopod',
#  'Somniosus',
#  'Somniosus pacificus',
#  'sonar',
#  'Sonardyne beacon',
#  'sooty dragonfish',
#  'southern spiny dreamer',
#  'Sparrowhawk',
#  'sparse tube feet impressions',
#  'Spatangidae',
#  'Spatangoida',
#  'Spatangus',
#  'Spatangus californicus',
#  'spatter',
#  'speckled rockfish',
#  'speckled scorpionfish',
#  'Spectrunculus',
#  'Spectrunculus grandis',
#  'Sphaerellaria',
#  'Sphaerodoridae',
#  'Sphaeronectes',
#  'Sphaeronectes christiansonae',
#  'Sphaeronectes gracilis',
#  'Sphaeronectes haddocki',
#  'Sphaeronectes tiburonae',
#  'Sphaeronectidae',
#  'Sphaerozoidae',
#  'Sphaerozoum',
#  'sphalerite',
#  'Sphyraena',
#  'Sphyraena argentea',
#  'Sphyraenidae',
#  'spicule',
#  'spider',
#  'spiderfish',
#  'spine',
#  'spinel',
#  'Spinulosacea',
#  'Spinulosida',
#  'spiny dogfish',
#  'spiny dreamer',
#  'spiny paralomis',
#  'spinycheek starsnout poacher',
#  'Spionida',
#  'Spionidae',
#  'Spiophanes',
#  'Spiophanes pallidus',
#  'Spirorbinae',
#  'Spirorbis',
#  'Spirularia',
#  'splitnose rockfish',
#  'spoke burrow cluster long',
#  'spoke burrow cluster short',
#  'sponge',
#  'Spongehead catshark',
#  'Spongodiscidae',
#  'spookfish',
#  'spoon worm',
#  'spot prawn',
#  'spot shrimp',
#  'spotfin-sculpin',
#  'spotted cuskeel',
#  'spotted ratfish',
#  'spotted rose snapper',
#  'SPS4',
#  'Spumellaria',
#  'Sputnik sponge',
#  'Spyridae',
#  'Squalidae',
#  'Squaliformes',
#  'Squalus',
#  'Squalus suckleyi',
#  'squarespot rockfish',
#  'squaretail',
#  'squat lobster',
#  'Squatinidae',
#  'Squatiniformes',
#  'squid',
#  'Squilla',
#  'Squilla biformis',
#  'Squillidae',
#  'Squilloidea',
#  'stalagmite',
#  'stalk',
#  'star radiolarian',
#  'starry flounder',
#  'starry rockfish',
#  'starry skate',
#  'Staurocalyptus',
#  'Staurocucumis',
#  'Staurocucumis abyssorum',
#  'STED',
#  'Stegastes',
#  'Stegastes rectifraenum',
#  'Stelechopus',
#  'Stellamedusa',
#  'Stellamedusa ventana',
#  'Stellamedusinae',
#  'Stelleroidea',
#  'Stenobrachius',
#  'Stenobrachius leucopsarus',
#  'stenoglossa',
#  'Stenorhynchus',
#  'Stenorhynchus debilis',
#  'Stephalia',
#  'Stephalia dilata',
#  'Stephanoberyciformes',
#  'Stephanomia',
#  'Stephanomia amphytridis ',
#  'Stephanomiidae',
#  'Stephanophyes',
#  'Stephanophyes superba',
#  'stereo camera calibration cube',
#  'Sternaspidae',
#  'Sternoptychidae',
#  'Sternoptychinae',
#  'Sternoptyx',
#  'Sternoptyx diaphana',
#  'Sternoptyx obscura',
#  'Sthenoniinae',
#  'Stichaeidae',
#  'Stichopodidae',
#  'Stigmatoteuthis',
#  'Stigmatoteuthis dofleini',
#  'still-photo camera',
#  'stipe',
#  'Stolidobranchia',
#  'Stolidobranchiata (suborder)',
#  'Stolonifera',
#  'Stomatopoda',
#  'Stomias',
#  'Stomias atriventer',
#  'Stomiidae',
#  'Stomiiformes',
#  'Stomiinae',
#  'Stomphia',
#  'Stomphia didemon',
#  'stone crab',
#  'stony-coral',
#  'Storthyngura',
#  'Storthyngura pulchra',
#  'stout blacksmelt',
#  'stramenopile',
#  'strawberry-anemone',
#  'Streetsia',
#  'Streetsia pronoides',
#  'Striatodoma',
#  'Striatodoma dorothea',
#  'stripefin poacher',
#  'stripetail rockfish',
#  'Stromateidae',
#  'Strongylocentrotidae',
#  'Strongylocentrotus',
#  'Strongylocentrotus cf. fragilis',
#  'Strongylocentrotus fragilis',
#  'Strongylocentrotus purpuratus',
#  'structured light',
#  'Styelidae',
#  'Stygiomedusa',
#  'Stygiomedusa gigantea',
#  'Stygiomedusinae',
#  'Stylaster',
#  'Stylaster californicus',
#  'Stylasterias',
#  'Stylasterias forreri',
#  'Stylasteridae',
#  'Stylatula',
#  'Stylatula elongata',
#  'Stylephoridae',
#  'Stylephorus',
#  'Stylephorus chordatus',
#  'Stylocordyla',
#  'Stylocordylidae',
#  'Subselliflorae',
#  'substrate composition',
#  'sucker row',
#  'Suction Sampler',
#  'Sufflamen',
#  'Sufflamen verres',
#  'sulfate mineral',
#  'sulfide',
#  'sulfide flux sensor',
#  'sulfide mineral',
#  'sulfur',
#  'sunbeam lampfish',
#  'sunlit water',
#  'surface water',
#  'surfperch',
#  'swallower',
#  'swallower chiasmodontid',
#  'swellhead snailfish',
#  'Swiftia',
#  'Swiftia kofoidi',
#  'Swiftia simplex',
#  'Swima',
#  'Swima bombiviridis',
#  'Swima fulgida',
#  'swimming',
#  'swimming bell',
#  'swing arm',
#  'swordfish squid',
#  'swordspine rockfish',
#  'Syllidae',
#  'Symbolophorus',
#  'Symbolophorus californiensis',
#  'Symphurinae',
#  'Symphurus',
#  'Symphurus oligomerus',
#  'Synallactes',
#  'Synallactidae',
#  'Synallactidae gen. et sp. indet.',
#  'Synaphobranchidae',
#  'Synodontidae',
#  'Synodontinae',
#  'Synodus',
#  'Synodus lacertinus',
#  'Synodus lucioceps',
#  'Systellaspis',
#  'Systellaspis braueri',
#  'Systellaspis braueri paucispinosa',
#  'Systellaspis cristata',
#  'Taaningichthys',
#  'Taaningichthys bathyphilus',
#  'Tactostoma',
#  'Tactostoma macropus',
#  'tadpole snailfish',
#  'tail',
#  'talc',
#  'Talismania',
#  'Talismania bifurcata',
#  'talus',
#  'talus chute',
#  'tan bristlemouth',
#  'Taningia',
#  'Taningia danae',
#  'Taoniinae',
#  'Taonius',
#  'Taonius borealis',
#  'Taonius pavo',
#  'tape cassette',
#  'tar',
#  'tar-ball',
#  'Tarletonbeania',
#  'Tarletonbeania crenularis',
#  'Tarletonbeania taylori',
#  'Tarsaster',
#  'Tealia',
#  'Tectillaria',
#  'telescopefish',
#  'temperate bass',
#  'temperature',
#  'Temperature Gradient Probe',
#  'temperature, pressure, conductivity sensor',
#  'Tenebrincola',
#  'Tenebrincola cukri',
#  'tentacle',
#  'Tentaculata',
#  'tephra',
#  'Tephra',
#  'Tephra collector',
#  'Terebella',
#  'Terebella californica',
#  'Terebellida',
#  'Terebellidae',
#  'Terebellides',
#  'Terebellides kobei',
#  'Terebratulina',
#  'Tergivelum',
#  'Tergivelum baldwinae',
#  'Tergivelum sp. A',
#  'Tessaradomidae',
#  'test',
#  'Test Tank',
#  'tether',
#  'Tetragonuridae',
#  'Tetragonurus',
#  'Tetragonurus cuvieri',
#  'Tetraodontiformes',
#  'Tetraplatia',
#  'Tetraplatia volitans',
#  'Tetronarce californica',
#  'Tetropoda',
#  'Tetrorchis',
#  'Tetrorchis erythrogaster',
#  'Tetrorchis sp. A',
#  'Teuthida',
#  'Teuthoidea',
#  'Teuthowenia',
#  'Teuthowenia megalops',
#  'Tevnia',
#  'Thalassicolla',
#  'Thalassicollida',
#  'Thalassinidea',
#  'Thalassinoidea',
#  'Thalassobathia',
#  'Thalassobathia pelagica',
#  'Thalassocalyce',
#  'Thalassocalyce inconstans',
#  'Thalassocalycida',
#  'Thalassocalycidae',
#  'Thalassosphaera',
#  'Thalassosphaerida',
#  'Thalia',
#  'Thalia democratica',
#  'Thaliacea',
#  'thecate-hydroid',
#  'Thecofilosea',
#  'Thecosomata',
#  'Thecostraca',
#  'Thenaria',
#  'Thenea',
#  'Thenea muricata',
#  'Theneidae',
#  'Theoperidae',
#  'Theragra',
#  'Theragra chalcogramma',
#  'Thermarces',
#  'Thermarces cerberus',
#  'Thermocouple Array',
#  'Thermopalia',
#  'Thermopalia taraxaca',
#  'Thetys',
#  'Thetys vagina',
#  'Theudoidea',
#  'Thioplaca',
#  'Thliptodon',
#  'Thliptodon diaphanus',
#  'Thliptodontinae',
#  'tholeiite',
#  'tholeitic basalt',
#  'Thoracica',
#  'thorny coral',
#  'thornyhead rockfish',
#  'threadfin angler',
#  'threadfin goosefish',
#  'threadfin grenadier',
#  'threadfin sculpin',
#  'threadfin snailfish',
#  'threadfin-slickhead',
#  'Three-color polycera',
#  'threebanded butterflyfish',
#  'thresher shark',
#  'Thrissacanthias',
#  'Thrissacanthias penicillatus',
#  'Thuesen, Erik',
#  'Thylacodes',
#  'Thylacodes squamigerus',
#  'Tiaranna',
#  'Tiaranna rotunda',
#  'Tiarannidae',
#  'Tiaropsidae',
#  'Tiaropsidium',
#  'Tiaropsidium kelseyi',
#  'Tiburon',
#  'Tiburonia',
#  'Tiburonia granrojo',
#  'Tiburoniinae',
#  'tiger rockfish',
#  'Tiltmeter',
#  'Tima',
#  'time-lapse camera',
#  'tire',
#  'Titanium Major Water Sampler',
#  'Tjalfiella',
#  'Tjalfiellidae',
#  'toadfish',
#  'Tochuina',
#  'Tochuina gigantea',
#  'Tomopterid eggcase',
#  'Tomopteridae',
#  'Tomopteris',
#  'Tomopteris nisseni',
#  'Tomopteris septentrionalis',
#  'Tongji MARS Package',
#  'tonguefish',
#  'Tonrometra',
#  'tooth',
#  'toothed whale',
#  'Torpedinidae',
#  'Torpediniformes',
#  'Torpedo',
#  'torpedo ray',
#  'Torquarator',
#  'Torquarator bullocki',
#  'Torquaratoridae',
#  'Torquaratoridae sp. 2',
#  'Torquaratoridae sp. 4',
#  'Torquaratoridae sp. 5',
#  'TorquaratoridaeA',
#  'TorquaratoridaeA sp. 1',
#  'TorquaratoridaeB',
#  'TorquaratoridaeB sp. 1',
#  'TorquaratoridaeB sp. 2',
#  'TorquaratoridaeB sp. 3',
#  'Torrea',
#  'TPC',
#  'Tracheophyta',
#  'Trachipteridae',
#  'Trachipterus',
#  'Trachipterus altivelis',
#  'Trachurus',
#  'Trachurus symmetricus',
#  'Trachylinae',
#  'Trachymedusae',
#  'trachyte',
#  'Track A',
#  'Track B',
#  'Track C',
#  'Track D',
#  'Track E',
#  'Track F',
#  'Track G',
#  'Track H',
#  'Track I',
#  'Transmissometer',
#  'transparent hatchetfish',
#  'trap',
#  'trash',
#  'Travisiopsis',
#  'trawl mark',
#  'treefish',
#  'trench',
#  'Tretodictyidae',
#  'Triacanthodidae',
#  'Triakidae',
#  'Triakinae',
#  'Trichobranchidae',
#  'Trichodesmium',
#  'Triphoturus',
#  'Triphoturus mexicanus',
#  'tripodfish',
#  'tripodfishes',
#  'Trissopathes',
#  'Trissopathes pseudotristicha',
#  'Tritonia',
#  'Tritonia diomedea',
#  'Tritonia festiva',
#  'Tritonia sp. A',
#  'Tritonia tetraquetra',
#  'Tritoniidae',
#  'Tritonioidea',
#  'Trochochaetidae',
#  'Trochoidea',
#  'Tromikosoma',
#  'Tromikosoma hispidum',
#  'Tromikosoma panamense',
#  'Tromikosoma sp. 1',
#  'trout',
#  'true cod',
#  'true coral',
#  'true crab',
#  'true leech',
#  'true limpet',
#  'true seal',
#  'true-soft-coral',
#  'tube',
#  'tube anemone',
#  'tube snail',
#  'tube-dwelling anemone',
#  'tube-nosed swimmer',
#  'tubefeet',
#  'tubeshoulder',
#  'tubing',
#  'tubular bryozoan',
#  'Tubularia',
#  'Tubularidae',
#  'Tubularoidea',
#  'tumbleweed anemone',
#  'tumulus',
#  'tuna',
#  'Tunicata',
#  'tunicate',
#  'Tuscarantha',
#  'Tuscarantha braueri',
#  'Tuscarantha luciae',
#  'Tuscaretta',
#  'Tuscaretta globosa',
#  'Tuscaridium',
#  'Tuscaridium cygneum',
#  'Tuscarilla',
#  'Tuscarilla campanella',
#  'Tuscarilla nationalis',
#  'Tuscarilla similis',
#  'Tuscarora',
#  'Tuscaroridae',
#  'tusk shell',
#  'tweezers',
#  'twoline eelpout',
#  'twospine bigscale',
#  'Typhloscolecidae',
#  'Ulmaridae',
#  'Ulmariidae',
#  'Ulva',
#  'Ulvaceae',
#  'Ulvales',
#  'Ulvophyceae',
#  'Umbellapathes',
#  'Umbellapathes bipinnata',
#  'Umbellula',
#  'Umbellula lindahli',
#  'Umbellula sp. 1',
#  'Umbellulidae',
#  'umbrellamouth gulper',
#  'unconsolidated',
#  'Unispionidae',
#  'Urasterias',
#  'Urasterias lincki',
#  'urchin',
#  'Urechinidae',
#  'Urechinina',
#  'Uria',
#  'Uria aalge',
#  'Urochordata',
#  'Urticina',
#  'USS Macon',
#  'v-shaped track',
#  'Valettiopsidae',
#  'Valettiopsis',
#  'Valettiopsis concava',
#  'Valvatacea',
#  'Valvatida',
#  'Valvifera',
#  'vampire squid',
#  'Vampyrocrossota',
#  'Vampyrocrossota childressi',
#  'Vampyromorpha',
#  'Vampyromorphida',
#  'Vampyroteuthidae',
#  'Vampyroteuthis',
#  'Vampyroteuthis infernalis',
#  'Vanadis',
#  'Vaqueros Formation',
#  'vascular plant',
#  'vein',
#  'Velamen',
#  'Velamen parallelum',
#  'Velatida',
#  'Velella',
#  'Velella velella',
#  'Velellidae',
#  'velvelt whalefish',
#  'Venefica',
#  'Venefica procera',
#  'Venefica tentaculata',
#  'Veneroida',
#  'vent fluid',
#  'Ventana',
#  'venting',
#  'Ventrifilosa',
#  'venus girdle',
#  "Verill's paralomis",
#  'Vermetidae',
#  'vermillion rockfish',
#  'vermillion seastar',
#  'Vertebrata',
#  'Verum',
#  'Verum proximum',
#  'Vesicomya',
#  'Vesicomya gigas',
#  'Vesicomya pacifica',
#  'vesicomyid-clam',
#  'Vesicomyidae',
#  'Vestimentifera',
#  'Vetigastropoda',
#  'Vibilioidea',
#  'vibraclaw',
#  'Vibracorer',
#  'Vibrapeeper',
#  'video mosaic',
#  'Vigtorniella',
#  'Vinciguerria',
#  'vinciguerria',
#  'Vinciguerria lucetia',
#  'Vinciguerria nimbaria',
#  'viperfish',
#  'Virgularia',
#  'Virgulariidae',
#  'Vitreledonella',
#  'Vitreledonella richardi',
#  'Vitreledonellidae',
#  'Vitreosalpa',
#  'Vitreosalpa gemini',
#  'viviparous blennies',
#  'viviparous brotula',
#  'Vogtia',
#  'Vogtia glabra',
#  'Vogtia pentacantha',
#  'Vogtia serrata',
#  'Vogtia spinosa',
#  'volcanic breccia',
#  'volcanic glass',
#  'volcanic mudstone',
#  'volcanic rock',
#  'volcanic sandstone',
#  'volcanic siltstone',
#  'volcaniclastic rock',
#  'volcaniclastic sediment',
#  'volcaniclastite',
#  'Volutidae',
#  'Voragonema',
#  'Voragonema laciniata',
#  'Voragonema pedunculata',
#  'Vrijenhoekia',
#  'Vrijenhoekia balaenophila',
#  'w-shaped track',
#  'Waffle Stomper',
#  'walleye pollock',
#  'warty sea pig',
#  'waryfish',
#  'water',
#  'Water lift',
#  'water-jellyfish',
#  'Water-lift',
#  'wave height sensor',
#  'Wax corer',
#  'weight',
#  'Western Flyer',
#  'whale',
#  'whale carcass',
#  'whale lice',
#  'whale mark',
#  'whalefish',
#  'Whaling',
#  'whipnose',
#  'whiptail gulper',
#  'whiptail ribbonfish',
#  'white goiter sponge',
#  'white lattice sponge',
#  'white ruffled sponge',
#  'white shark',
#  'white skate',
#  'white smoker',
#  'white trumpet sponge',
#  'whitespotted greenling',
#  'wide shallow grooved track',
#  'widow rockfish',
#  'wolf eel',
#  'wolffish',
#  'wood',
#  'wood fall experiment',
#  'wood fishing trap',
#  'worm',
#  'worm snail',
#  'wrasse',
#  'Xantic sargo',
#  'Xeneretmus',
#  'Xeneretmus latifrons',
#  'Xeneretmus ritteri',
#  'xenolith',
#  'Xenophyophorea',
#  'Xenophyophoroidea',
#  'Xenoturbella',
#  'Xenoturbellida',
#  'Xenoturbellidae',
#  'Xystreurys',
#  'Xystreurys liolepis',
#  'y-patterned moray',
#  'yellow goiter sponge',
#  'yellow picasso sponge',
#  'yellow ruffled sponge',
#  'yellow snapper',
#  'yellowchin sculpin',
#  'yelloweye rockfish',
#  'yellowfin surgeonfish',
#  'yellowtail rockfish',
#  'Yoda',
#  'Yoda sp. A',
#  'Yoda sp. B',
#  'Yoldia',
#  'Yoldiidae',
#  'Zalembius',
#  'Zalembius rosaceus',
#  'Zalophus',
#  'Zalophus californianus',
#  'Zanclidae',
#  'Zanclus',
#  'Zanclus cornutus',
#  'Zaniolepididae',
#  'Zaniolepidinae',
#  'Zaniolepis',
#  'Zaniolepis frenata',
#  'Zaniolepis latipinnis',
#  'Zenometridae',
#  'zeolite',
#  'zircon',
#  'Zoantharia',
#  'zoanthid',
#  'Zoanthidea',
#  'Zoarcidae',
#  'zooid',
#  'zooplankton',
#  'Zoroaster',
#  'Zoroaster evermanni',
#  'Zoroasteridae',
#  'Zostera',
#  'Zostera marina',
#  'Zosteraceae']

# %%
# Get the root node of the concept hierarchy
url = concept_url + "/root"
root = get(url)
show("GET: " + url, root)
# Out:
# --- GET: http://dsg.mbari.org/kb/v1/concept/root
# {'alternateNames': ['root'], 'descriptors': [], 'media': [], 'name': 'object'}

# %%
# Get a concept by name
url = concept_url + "/Nanomia bijuga"
concept = get(url)
show("GET: " + url, concept)
# Out:
# --- GET: http://dsg.mbari.org/kb/v1/concept/Nanomia bijuga
# {'alternateNames': [],
#  'descriptors': [{'linkName': 'is-bioluminescent',
#                   'linkValue': 'bioluminescent',
#                   'toConcept': 'self'}],
#  'media': [{'caption': '',
#             'credit': 'MBARI 2001: V2100-05\n',
#             'isPrimary': False,
#             'mimeType': 'image/png',
#             'url': 'http://dsg.mbari.org/images/dsg/external/Cnidaria/Siphonophora/Nanomia_bijuga_01.png'},
#            {'caption': '',
#             'credit': 'MBARI 2010: D199',
#             'isPrimary': False,
#             'mimeType': 'image/png',
#             'url': 'http://dsg.mbari.org/images/dsg/external/Cnidaria/Siphonophora/Nanomia_bijuga_02.png'},
#            {'caption': '',
#             'credit': 'MBARI 2010: D199',
#             'isPrimary': False,
#             'mimeType': 'image/png',
#             'url': 'http://dsg.mbari.org/images/dsg/external/Cnidaria/Siphonophora/Nanomia_bijuga_05.png'},
#            {'caption': 'Close up of nectosome',
#             'credit': 'MBARI 2012: D411',
#             'isPrimary': True,
#             'mimeType': 'image/png',
#             'url': 'http://dsg.mbari.org/images/dsg/external/Cnidaria/Siphonophora/Nanomia_bijuga_03.png'},
#            {'caption': 'Close up of siphosome',
#             'credit': 'MBARI 2012: D411',
#             'isPrimary': False,
#             'mimeType': 'image/png',
#             'url': 'http://dsg.mbari.org/images/dsg/external/Cnidaria/Siphonophora/Nanomia_bijuga_04.png'},
#            {'caption': '',
#             'credit': 'MBARI 2011: D326',
#             'isPrimary': False,
#             'mimeType': 'image/png',
#             'url': 'http://dsg.mbari.org/images/dsg/external/Cnidaria/Siphonophora/Nanomia_bijuga_06.png'},
#            {'caption': 'Full gastrozooid',
#             'credit': 'MBARI 2012: D411',
#             'isPrimary': False,
#             'mimeType': 'image/png',
#             'url': 'http://dsg.mbari.org/images/dsg/external/Cnidaria/Siphonophora/Nanomia_bijuga_07.png'}],
#  'name': 'Nanomia bijuga',
#  'rank': 'species'}

# %% [markdown]
# ## Phylogeny API
#
# This API fetches either the ancestors __or__ the descendants of a concept (e.g. Phylogenetic tree)

# %%
# Fetch ancestors
url = phylogeny_url + "/up/Asteroidea"
p = get(url)
show("Get: " + url, p)
# Out:
# --- Get: http://dsg.mbari.org/kb/v1/phylogeny/up/Asteroidea
# {'children': [{'children': [{'children': [{'children': [{'children': [{'children': [{'children': [{'children': [],
#                                                                                                    'name': 'Asteroidea',
#                                                                                                    'rank': 'class'}],
#                                                                                      'name': 'Asterozoa',
#                                                                                      'rank': 'subphylum'}],
#                                                                        'name': 'Echinodermata',
#                                                                        'rank': 'phylum'}],
#                                                          'name': 'Animalia',
#                                                          'rank': 'kingdom'}],
#                                            'name': 'Eukaryota',
#                                            'rank': 'superkingdom'}],
#                              'name': 'marine organism',
#                              'rank': ''}],
#                'name': 'physical object',
#                'rank': ''}],
#  'name': 'object',
#  'rank': ''}

# %%
# Fetch descendants
url = phylogeny_url + "/down/Asteroidea"
p = get(url)
show("Get: " + url, p)
# Out:
# --- Get: http://dsg.mbari.org/kb/v1/phylogeny/down/Asteroidea
# {'children': [{'children': [], 'name': 'Asteroidea sp. 9', 'rank': 'species'},
#               {'children': [], 'name': 'Asteroidea sp. 6', 'rank': 'species'},
#               {'children': [{'children': [{'children': [{'children': [],
#                                                          'name': 'Brisinga',
#                                                          'rank': 'genus'},
#                                                         {'children': [],
#                                                          'name': 'Hymenodiscus',
#                                                          'rank': 'genus'}],
#                                            'name': 'Brisingidae',
#                                            'rank': 'family'},
#                                           {'children': [{'children': [{'children': [],
#                                                                        'name': 'Freyellaster '
#                                                                                'fecundus',
#                                                                        'rank': 'species'}],
#                                                          'name': 'Freyellaster',
#                                                          'rank': 'genus'}],
#                                            'name': 'Freyellidae',
#                                            'rank': 'family'}],
#                              'name': 'Brisingida',
#                              'rank': 'order'},
#                             {'children': [{'children': [{'children': [],
#                                                          'name': 'Pedicellasteridae '
#                                                                  'sp. 2',
#                                                          'rank': 'species'},
#                                                         {'children': [],
#                                                          'name': 'Tarsaster',
#                                                          'rank': 'genus'},
#                                                         {'children': [],
#                                                          'name': 'Hydrasterias',
#                                                          'rank': 'genus'},
#                                                         {'children': [{'children': [],
#                                                                        'name': 'Ampheraster '
#                                                                                'marianus',
#                                                                        'rank': 'species'}],
#                                                          'name': 'Ampheraster',
#                                                          'rank': 'genus'},
#                                                         {'children': [],
#                                                          'name': 'Anteliaster',
#                                                          'rank': 'genus'},
#                                                         {'children': [],
#                                                          'name': 'Pedicellaster',
#                                                          'rank': 'genus'}],
#                                            'name': 'Pedicellasteridae',
#                                            'rank': 'family'},
#                                           {'children': [{'children': [{'children': [],
#                                                                        'name': 'Rathbunaster '
#                                                                                'californicus',
#                                                                        'rank': 'species'}],
#                                                          'name': 'Rathbunaster',
#                                                          'rank': 'genus'},
#                                                         {'children': [],
#                                                          'name': 'Leptasterias',
#                                                          'rank': 'genus'},
#                                                         {'children': [{'children': [],
#                                                                        'name': 'Orthasterias '
#                                                                                'koehleri',
#                                                                        'rank': ''}],
#                                                          'name': 'Orthasterias',
#                                                          'rank': 'genus'},
#                                                         {'children': [{'children': [],
#                                                                        'name': 'Stylasterias '
#                                                                                'forreri',
#                                                                        'rank': 'species'}],
#                                                          'name': 'Stylasterias',
#                                                          'rank': 'genus'},
#                                                         {'children': [{'children': [],
#                                                                        'name': 'Urasterias '
#                                                                                'lincki',
#                                                                        'rank': 'species'}],
#                                                          'name': 'Urasterias',
#                                                          'rank': 'genus'},
#                                                         {'children': [{'children': [],
#                                                                        'name': 'Pisaster '
#                                                                                'giganteus',
#                                                                        'rank': 'species'},
#                                                                       {'children': [],
#                                                                        'name': 'Pisaster '
#                                                                                'brevispinus',
#                                                                        'rank': 'species'}],
#                                                          'name': 'Pisaster',
#                                                          'rank': 'genus'}],
#                                            'name': 'Asteriidae',
#                                            'rank': 'family'},
#                                           {'children': [{'children': [{'children': [],
#                                                                        'name': 'Pycnopodia '
#                                                                                'helianthoides',
#                                                                        'rank': 'species'}],
#                                                          'name': 'Pycnopodia',
#                                                          'rank': 'genus'}],
#                                            'name': 'Pycnopodiidae',
#                                            'rank': 'family'},
#                                           {'children': [{'children': [{'children': [],
#                                                                        'name': 'Paulasterias '
#                                                                                'mcclaini',
#                                                                        'rank': 'species'}],
#                                                          'name': 'Paulasterias',
#                                                          'rank': 'genus'}],
#                                            'name': 'Paulasteriidae',
#                                            'rank': 'family'},
#                                           {'children': [{'children': [{'children': [],
#                                                                        'name': 'Sagenaster '
#                                                                                'evermanni',
#                                                                        'rank': 'species'}],
#                                                          'name': 'Sagenaster',
#                                                          'rank': 'genus'},
#                                                         {'children': [],
#                                                          'name': 'Zoroaster',
#                                                          'rank': 'genus'},
#                                                         {'children': [{'children': [],
#                                                                        'name': 'Myxoderma '
#                                                                                'sacculatum',
#                                                                        'rank': 'species'},
#                                                                       {'children': [],
#                                                                        'name': 'Myxoderma '
#                                                                                'platyacanthum',
#                                                                        'rank': 'species'}],
#                                                          'name': 'Myxoderma',
#                                                          'rank': 'genus'}],
#                                            'name': 'Zoroasteridae',
#                                            'rank': 'family'}],
#                              'name': 'Forcipulatida',
#                              'rank': 'order'}],
#                'name': 'Forcipulatacea',
#                'rank': 'superorder'},
#               {'children': [{'children': [{'children': [{'children': [{'children': [],
#                                                                        'name': 'Henricia '
#                                                                                'sp. '
#                                                                                '1',
#                                                                        'rank': 'species'},
#                                                                       {'children': [],
#                                                                        'name': 'Henricia '
#                                                                                'cf. '
#                                                                                'asthenactis',
#                                                                        'rank': 'genus'}],
#                                                          'name': 'Henricia',
#                                                          'rank': 'genus'},
#                                                         {'children': [],
#                                                          'name': 'Echinaster',
#                                                          'rank': 'genus'}],
#                                            'name': 'Echinasteridae',
#                                            'rank': 'family'}],
#                              'name': 'Spinulosida',
#                              'rank': 'order'}],
#                'name': 'Spinulosacea',
#                'rank': 'superorder'},
#               {'children': [], 'name': 'Asteroidea sp. 7', 'rank': 'genus'},
#               {'children': [{'children': [{'children': [{'children': [{'children': [],
#                                                                        'name': 'Benthopecten '
#                                                                                'claviger',
#                                                                        'rank': 'species'}],
#                                                          'name': 'Benthopecten',
#                                                          'rank': 'genus'},
#                                                         {'children': [],
#                                                          'name': 'Nearchaster',
#                                                          'rank': 'genus'}],
#                                            'name': 'Benthopectinidae',
#                                            'rank': 'family'}],
#                              'name': 'Notomyotida',
#                              'rank': 'order'},
#                             {'children': [{'children': [{'children': [{'children': [],
#                                                                        'name': 'Nymphaster '
#                                                                                'diomedeae',
#                                                                        'rank': ''}],
#                                                          'name': 'Nymphaster',
#                                                          'rank': 'genus'},
#                                                         {'children': [{'children': [],
#                                                                        'name': 'Bathyceramaster '
#                                                                                'elegans',
#                                                                        'rank': 'species'},
#                                                                       {'children': [],
#                                                                        'name': 'Bathyceramaster '
#                                                                                'careyi',
#                                                                        'rank': 'species'}],
#                                                          'name': 'Bathyceramaster',
#                                                          'rank': 'genus'},
#                                                         {'children': [{'children': [],
#                                                                        'name': 'Sibogaster '
#                                                                                'nieseni ',
#                                                                        'rank': 'species'}],
#                                                          'name': 'Sibogaster',
#                                                          'rank': 'genus'},
#                                                         {'children': [{'children': [],
#                                                                        'name': 'Circeaster '
#                                                                                'pullus',
#                                                                        'rank': 'species'}],
#                                                          'name': 'Circeaster',
#                                                          'rank': 'genus'},
#                                                         {'children': [{'children': [],
#                                                                        'name': 'Calliderma '
#                                                                                'emma',
#                                                                        'rank': 'species'}],
#                                                          'name': 'Calliderma',
#                                                          'rank': 'genus'},
#                                                         {'children': [{'children': [],
#                                                                        'name': 'Ceramaster '
#                                                                                'clarki',
#                                                                        'rank': 'species'},
#                                                                       {'children': [],
#                                                                        'name': 'Ceramaster '
#                                                                                'pointsurae',
#                                                                        'rank': 'species'},
#                                                                       {'children': [],
#                                                                        'name': 'Ceramaster '
#                                                                                'patagonicus',
#                                                                        'rank': 'species'}],
#                                                          'name': 'Ceramaster',
#                                                          'rank': 'genus'},
#                                                         {'children': [{'children': [{'children': [],
#                                                                                      'name': 'Evoplosoma '
#                                                                                              'claguei',
#                                                                                      'rank': 'species'},
#                                                                                     {'children': [],
#                                                                                      'name': 'Evoplosoma '
#                                                                                              'voratus',
#                                                                                      'rank': ''}],
#                                                                        'name': 'Evoplosoma',
#                                                                        'rank': 'genus'},
#                                                                       {'children': [{'children': [],
#                                                                                      'name': 'Hippasteria '
#                                                                                              'tiburoni',
#                                                                                      'rank': 'species'},
#                                                                                     {'children': [],
#                                                                                      'name': 'Hippasteria '
#                                                                                              'lepidonotus',
#                                                                                      'rank': 'species'},
#                                                                                     {'children': [],
#                                                                                      'name': 'Hippasteria '
#                                                                                              'phrygiana',
#                                                                                      'rank': 'species'},
#                                                                                     {'children': [],
#                                                                                      'name': 'Hippasteria '
#                                                                                              'californica',
#                                                                                      'rank': 'species'}],
#                                                                        'name': 'Hippasteria',
#                                                                        'rank': 'genus'}],
#                                                          'name': 'Hippasterinae',
#                                                          'rank': 'subfamily'},
#                                                         {'children': [{'children': [],
#                                                                        'name': 'Pillsburiaster '
#                                                                                'ernesti',
#                                                                        'rank': 'species'}],
#                                                          'name': 'Pillsburiaster',
#                                                          'rank': 'genus'},
#                                                         {'children': [{'children': [],
#                                                                        'name': 'Mediaster '
#                                                                                'aequalis',
#                                                                        'rank': 'species'},
#                                                                       {'children': [],
#                                                                        'name': 'Mediaster '
#                                                                                'tenellus',
#                                                                        'rank': 'species'}],
#                                                          'name': 'Mediaster',
#                                                          'rank': 'genus'}],
#                                            'name': 'Goniasteridae',
#                                            'rank': 'family'},
#                                           {'children': [{'children': [{'children': [],
#                                                                        'name': 'Poraniopsis '
#                                                                                'inflata',
#                                                                        'rank': 'species'}],
#                                                          'name': 'Poraniopsis',
#                                                          'rank': 'genus'},
#                                                         {'children': [{'children': [],
#                                                                        'name': 'Bathyporania '
#                                                                                'ascendens',
#                                                                        'rank': 'species'}],
#                                                          'name': 'Bathyporania',
#                                                          'rank': 'genus'}],
#                                            'name': 'Poraniidae',
#                                            'rank': 'family'},
#                                           {'children': [{'children': [{'children': [],
#                                                                        'name': 'Dermasterias '
#                                                                                'imbricata',
#                                                                        'rank': 'species'}],
#                                                          'name': 'Dermasterias',
#                                                          'rank': 'genus'}],
#                                            'name': 'Asteropseidae',
#                                            'rank': 'family'},
#                                           {'children': [{'children': [{'children': [],
#                                                                        'name': 'Anseropoda '
#                                                                                'insignis',
#                                                                        'rank': 'species'}],
#                                                          'name': 'Anseropoda',
#                                                          'rank': 'genus'},
#                                                         {'children': [],
#                                                          'name': 'Asterina',
#                                                          'rank': 'genus'},
#                                                         {'children': [{'children': [],
#                                                                        'name': 'Patiria '
#                                                                                'miniata',
#                                                                        'rank': 'species'}],
#                                                          'name': 'Patiria',
#                                                          'rank': 'genus'}],
#                                            'name': 'Asterinidae',
#                                            'rank': 'family'},
#                                           {'children': [{'children': [{'children': [],
#                                                                        'name': 'Heterozonias '
#                                                                                'alternatus',
#                                                                        'rank': 'species'}],
#                                                          'name': 'Heterozonias',
#                                                          'rank': 'genus'},
#                                                         {'children': [{'children': [],
#                                                                        'name': 'Crossaster '
#                                                                                'borealis',
#                                                                        'rank': 'species'}],
#                                                          'name': 'Crossaster',
#                                                          'rank': 'genus'},
#                                                         {'children': [{'children': [],
#                                                                        'name': 'Lophaster '
#                                                                                'furcilliger',
#                                                                        'rank': 'species'}],
#                                                          'name': 'Lophaster',
#                                                          'rank': 'genus'},
#                                                         {'children': [{'children': [],
#                                                                        'name': 'Solaster '
#                                                                                'endeca',
#                                                                        'rank': 'species'},
#                                                                       {'children': [],
#                                                                        'name': 'Solaster '
#                                                                                'hypothrissus',
#                                                                        'rank': 'species'}],
#                                                          'name': 'Solaster',
#                                                          'rank': 'genus'}],
#                                            'name': 'Solasteridae',
#                                            'rank': 'family'}],
#                              'name': 'Valvatida',
#                              'rank': 'order'},
#                             {'children': [{'children': [{'children': [{'children': [],
#                                                                        'name': 'Pseudarchaster '
#                                                                                'dissonus',
#                                                                        'rank': 'species'}],
#                                                          'name': 'Pseudarchaster',
#                                                          'rank': 'genus'}],
#                                            'name': 'Pseudarchasteridae',
#                                            'rank': 'family'},
#                                           {'children': [{'children': [{'children': [],
#                                                                        'name': 'Dytaster '
#                                                                                'sp. '
#                                                                                '1',
#                                                                        'rank': 'species'},
#                                                                       {'children': [],
#                                                                        'name': 'Dytaster '
#                                                                                'gilberti',
#                                                                        'rank': 'species'}],
#                                                          'name': 'Dytaster',
#                                                          'rank': 'genus'},
#                                                         {'children': [{'children': [],
#                                                                        'name': 'Thrissacanthias '
#                                                                                'penicillatus',
#                                                                        'rank': 'species'}],
#                                                          'name': 'Thrissacanthias',
#                                                          'rank': 'genus'},
#                                                         {'children': [{'children': [],
#                                                                        'name': 'Leptychaster '
#                                                                                'anomalus',
#                                                                        'rank': 'species'}],
#                                                          'name': 'Leptychaster',
#                                                          'rank': 'genus'},
#                                                         {'children': [],
#                                                          'name': 'Astropecten',
#                                                          'rank': 'genus'},
#                                                         {'children': [],
#                                                          'name': 'Dipsacaster',
#                                                          'rank': 'genus'}],
#                                            'name': 'Astropectinidae',
#                                            'rank': 'family'},
#                                           {'children': [{'children': [{'children': [],
#                                                                        'name': 'Ctenodiscus '
#                                                                                'crispatus',
#                                                                        'rank': 'species'}],
#                                                          'name': 'Ctenodiscus',
#                                                          'rank': 'genus'}],
#                                            'name': 'Ctenodiscidae',
#                                            'rank': 'family'},
#                                           {'children': [],
#                                            'name': 'Goniopectinidae',
#                                            'rank': 'family'},
#                                           {'children': [{'children': [{'children': [],
#                                                                        'name': 'Luidia '
#                                                                                'foliolata',
#                                                                        'rank': 'species'}],
#                                                          'name': 'Luidia',
#                                                          'rank': 'genus'}],
#                                            'name': 'Luidiidae',
#                                            'rank': 'family'},
#                                           {'children': [{'children': [{'children': [],
#                                                                        'name': 'Radiaster '
#                                                                                'sp. '
#                                                                                '1',
#                                                                        'rank': 'species'}],
#                                                          'name': 'Radiaster',
#                                                          'rank': 'genus'}],
#                                            'name': 'Radiasteridae',
#                                            'rank': 'family'}],
#                              'name': 'Paxillosida',
#                              'rank': 'order'}],
#                'name': 'Valvatacea',
#                'rank': 'superorder'},
#               {'children': [], 'name': 'Asteroidea sp. 3', 'rank': ''},
#               {'children': [], 'name': 'Asteroidea sp. 4', 'rank': 'species'},
#               {'children': [], 'name': 'Asteroidea sp. 1', 'rank': 'species'},
#               {'children': [{'children': [{'children': [{'children': [],
#                                                          'name': 'Peribolaster '
#                                                                  'biserialis',
#                                                          'rank': 'species'}],
#                                            'name': 'Peribolaster',
#                                            'rank': 'genus'}],
#                              'name': 'Korethrasteridae',
#                              'rank': 'family'},
#                             {'children': [{'children': [{'children': [],
#                                                          'name': 'Asthenactis '
#                                                                  'fisheri',
#                                                          'rank': 'species'},
#                                                         {'children': [],
#                                                          'name': 'Asthenactis '
#                                                                  'papyraceus',
#                                                          'rank': 'species'}],
#                                            'name': 'Asthenactis',
#                                            'rank': 'genus'},
#                                           {'children': [],
#                                            'name': 'Pythonaster',
#                                            'rank': 'genus'}],
#                              'name': 'Myxasteridae',
#                              'rank': 'family'},
#                             {'children': [{'children': [],
#                                            'name': 'Pteraster',
#                                            'rank': 'genus'},
#                                           {'children': [{'children': [],
#                                                          'name': 'Hymenaster '
#                                                                  'koehleri',
#                                                          'rank': 'species'}],
#                                            'name': 'Hymenaster',
#                                            'rank': 'genus'}],
#                              'name': 'Pterasteridae',
#                              'rank': 'family'},
#                             {'children': [],
#                              'name': 'Caymanostellidae',
#                              'rank': 'family'}],
#                'name': 'Velatida',
#                'rank': 'order'},
#               {'children': [], 'name': 'Asteroidea sp. 8', 'rank': ''},
#               {'children': [], 'name': 'Asteroidea sp. 5', 'rank': 'species'},
#               {'children': [], 'name': 'Asteroidea sp. 2', 'rank': 'species'}],
#  'name': 'Asteroidea',
#  'rank': 'class'}

# %% [markdown]
# ## Links API
#
# Links are predefined associations that can be used for annotations. Think of an association as
# additional descriptive information that can be applied to an annotation. In our VARS
# knowledgebase, a link can be used by a concept __and__ any of its descendants. We
# have found it's important to define and constrain. When annotating, we need to know what links
# can be used for a particular concept.

# %%
# Find links for a concept
url = links_url + "/Asteroidea"
p = get(url)
show("GET: " + url, p)
# Out:
# --- GET: http://dsg.mbari.org/kb/v1/links/Asteroidea
# [{'linkName': 'age-days', 'linkValue': '0', 'toConcept': 'self'},
#  {'linkName': 'age-months', 'linkValue': '0', 'toConcept': 'self'},
#  {'linkName': 'age-seconds', 'linkValue': '0', 'toConcept': 'self'},
#  {'linkName': 'age-years', 'linkValue': '0', 'toConcept': 'self'},
#  {'linkName': 'arranging', 'linkValue': 'nil', 'toConcept': 'physical object'},
#  {'linkName': 'attaching-to',
#   'linkValue': 'nil',
#   'toConcept': 'physical object'},
#  {'linkName': 'audio-comment', 'linkValue': 'nil', 'toConcept': 'self'},
#  {'linkName': 'bioluminescing', 'linkValue': 'nil', 'toConcept': 'nil'},
#  {'linkName': 'broken', 'linkValue': 'nil', 'toConcept': 'nil'},
#  {'linkName': 'bubbling', 'linkValue': 'nil', 'toConcept': 'nil'},
#  {'linkName': 'buried', 'linkValue': 'nil', 'toConcept': 'nil'},
#  {'linkName': 'burrowing', 'linkValue': 'nil', 'toConcept': 'nil'},
#  {'linkName': 'catching', 'linkValue': 'nil', 'toConcept': 'physical object'},
#  {'linkName': 'caught-in', 'linkValue': 'nil', 'toConcept': 'physical object'},
#  {'linkName': 'changing', 'linkValue': 'nil', 'toConcept': 'nil'},
#  {'linkName': 'changing', 'linkValue': 'color', 'toConcept': 'object'},
#  {'linkName': 'collapsed', 'linkValue': 'nil', 'toConcept': 'nil'},
#  {'linkName': 'colliding-with',
#   'linkValue': 'nil',
#   'toConcept': 'physical object'},
#  {'linkName': 'comment', 'linkValue': 'nil', 'toConcept': 'human'},
#  {'linkName': 'comment', 'linkValue': 'nil', 'toConcept': 'self'},
#  {'linkName': 'composed-of',
#   'linkValue': 'nil',
#   'toConcept': 'physical object'},
#  {'linkName': 'connecting', 'linkValue': 'nil', 'toConcept': 'physical object'},
#  {'linkName': 'contacts', 'linkValue': 'nil', 'toConcept': 'physical object'},
#  {'linkName': 'contains', 'linkValue': 'nil', 'toConcept': 'physical object'},
#  {'linkName': 'crawling', 'linkValue': 'nil', 'toConcept': 'nil'},
#  {'linkName': 'curled-around-by',
#   'linkValue': 'nil',
#   'toConcept': 'physical object'},
#  {'linkName': 'curling', 'linkValue': 'nil', 'toConcept': 'nil'},
#  {'linkName': 'curling-around',
#   'linkValue': 'nil',
#   'toConcept': 'physical object'},
#  {'linkName': 'cutting', 'linkValue': 'nil', 'toConcept': 'nil'},
#  {'linkName': 'damaged', 'linkValue': 'nil', 'toConcept': 'nil'},
#  {'linkName': 'deployed-by', 'linkValue': 'nil', 'toConcept': 'equipment'},
#  {'linkName': 'disconnecting',
#   'linkValue': 'nil',
#   'toConcept': 'physical object'},
#  {'linkName': 'display-mode',
#   'linkValue': 'auxiliary-camera',
#   'toConcept': 'self'},
#  {'linkName': 'display-mode', 'linkValue': 'Coolpix', 'toConcept': 'self'},
#  {'linkName': 'display-mode', 'linkValue': 'overlay', 'toConcept': 'self'},
#  {'linkName': 'display-mode', 'linkValue': 'shore-link', 'toConcept': 'self'},
#  {'linkName': 'display-mode', 'linkValue': 'time-code', 'toConcept': 'self'},
#  {'linkName': 'diving', 'linkValue': 'nil', 'toConcept': 'nil'},
#  {'linkName': 'drifting', 'linkValue': 'nil', 'toConcept': 'nil'},
#  {'linkName': 'dropped-by', 'linkValue': 'nil', 'toConcept': 'physical object'},
#  {'linkName': 'dsg-climate', 'linkValue': 'nil', 'toConcept': 'self'},
#  {'linkName': 'dsg-commercial-use', 'linkValue': 'nil', 'toConcept': 'self'},
#  {'linkName': 'dsg-consulting-taxonomist',
#   'linkValue': 'Alexander Martynov, Zoological Museum, Moscow State '
#                'University, Moscow, Russia.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-consulting-taxonomist',
#   'linkValue': 'Anders Warén, Swedish Museum of Natural History, Stockholm, '
#                'Sweden.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-consulting-taxonomist',
#   'linkValue': 'Andrey Gebruk and Antonia Rogacheva, Russian Academy of '
#                'Sciences, Moscow Russia.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-consulting-taxonomist',
#   'linkValue': 'Christopher Mah, Smithsonian Natural History Museum.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-consulting-taxonomist',
#   'linkValue': 'Daphne Fautin, University of Kansas.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-consulting-taxonomist',
#   'linkValue': 'David Ebert, Moss Landing Marine Laboratories.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-consulting-taxonomist',
#   'linkValue': 'David Pawson, National Museum of Natural History, Smithsonian '
#                'Institution.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-consulting-taxonomist',
#   'linkValue': 'David Stein, NOAA NMFS National Systematics Laboratory, '
#                'National Museum of Natural History.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-consulting-taxonomist',
#   'linkValue': 'Donna Kline, Moss Landing Marine Laboratories, Moss Landing, '
#                'CA.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-consulting-taxonomist',
#   'linkValue': 'Dr. Nuria Mendez, Instituto de Ciencias del Mar y Limnología, '
#                'Mazatlán.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-consulting-taxonomist',
#   'linkValue': 'Erik Thuesen, Evergreen State College, Olympia, WA, USA.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-consulting-taxonomist',
#   'linkValue': 'Gary Williams, California Academy of Sciences.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-consulting-taxonomist',
#   'linkValue': 'Greg Rouse, Scripps Institute of Oceanography.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-consulting-taxonomist',
#   'linkValue': 'Gregor Cailliet, Moss Landing Marine Laboratories.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-consulting-taxonomist',
#   'linkValue': 'H.J. Walker, Jr., Collection Manager, Marine Vertebrate '
#                'Collection, Scripps Institution of Oceanography.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-consulting-taxonomist',
#   'linkValue': 'Henry Reiswig, University of Victoria, BC.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-consulting-taxonomist',
#   'linkValue': 'Hsuan-Ching Ho, National Museum of Marine Biology Checheng, '
#                'Pingtung, Taiwan.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-consulting-taxonomist',
#   'linkValue': 'James H. McLean, Curator Emeritus, Natural History Museum of '
#                'Los Angeles County.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-consulting-taxonomist',
#   'linkValue': 'Janet Voight, Associate Curator, Invertebrates, The Field '
#                'Museum.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-consulting-taxonomist',
#   'linkValue': "Jeff Drazen, University of Hawai'i at Manoa.",
#   'toConcept': 'self'},
#  {'linkName': 'dsg-consulting-taxonomist',
#   'linkValue': 'Jose Leonardo Castillo-Geniz, Instituto Nacional de Pesca y '
#                'Acuacultura, Centro Regional de Investigación Pesquera de '
#                'Ensenada, Baja California.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-consulting-taxonomist',
#   'linkValue': 'Joseph Bizzarro, University of Washington, Seattle.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-consulting-taxonomist',
#   'linkValue': 'Karen Osborn, Smithsonian Natural History Museum.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-consulting-taxonomist',
#   'linkValue': 'Kuhnz L., MBARI; Holland, N., Scripps Insitute of '
#                'Oceanography; Osborn, K., Smithsonian Natural History Museum.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-consulting-taxonomist',
#   'linkValue': 'Larry Madin, Woods Hole Oceanographic Institution.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-consulting-taxonomist',
#   'linkValue': 'Lawrence L. Lovell, Marine Biology Laboratory Sanitation '
#                'Districts of Los Angeles County, California.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-consulting-taxonomist',
#   'linkValue': 'Mary Wicksten, Professor, Texas A&M University, College '
#                'Station, Texas.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-consulting-taxonomist',
#   'linkValue': 'Mary Yoklavich, Research Fishery Biologist, Supervisor NOAA '
#                'Fisheries, Santa Cruz, CA.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-consulting-taxonomist',
#   'linkValue': 'Milton Love, Research Biologist, Marine Science Institute, '
#                'University of California, Santa Barbara.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-consulting-taxonomist',
#   'linkValue': 'Natalya Gallo, Ph.D. Candidate, Biological Oceanography, '
#                'Scripps Institution of Oceanography, UCSD.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-consulting-taxonomist',
#   'linkValue': 'nil',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-consulting-taxonomist',
#   'linkValue': 'Philip R. Pugh, National Oceanographic Centre.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-consulting-taxonomist',
#   'linkValue': 'Richard E. Young, Professor of Oceanography, University of '
#                'Hawaii.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-consulting-taxonomist',
#   'linkValue': 'Richard Mooi, California Academy of Sciences, San Francisco, '
#                'California.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-consulting-taxonomist',
#   'linkValue': 'Robert Lea, Research Associate Ichthyology, California Academy '
#                'of Sciences.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-consulting-taxonomist',
#   'linkValue': 'Shannon Johnson, MBARI.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-consulting-taxonomist',
#   'linkValue': 'Stace Beaulieu, Woods Hole Oceanographic Institution.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-consulting-taxonomist',
#   'linkValue': 'Theodore Pietsch, University of Washington Professor, Aquatic '
#                '& Fishery Sciences Curator of Fishes, Burke Museum of Natural '
#                'History and Culture.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-consulting-taxonomist',
#   'linkValue': 'Tomio Iwamoto, California Academy of Sciences.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-consulting-taxonomist',
#   'linkValue': 'W.C. Austin, Khoyatan Marine Laboratory, North Saanich, BC, '
#                'Canada.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-depth-distribution',
#   'linkValue': 'nil',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-description',
#   'linkValue': "Bill Chadwick's volcanic ash collecting buckets.",
#   'toConcept': 'self'},
#  {'linkName': 'dsg-description',
#   'linkValue': 'Primarily an infaunal organism. This concept is used only '
#                'after examination of a sample.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-description',
#   'linkValue': 'This concept is to be used only after examination of a sample.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-genetic-assessment',
#   'linkValue': 'nil',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-habitat', 'linkValue': 'Bathypelagic.', 'toConcept': 'self'},
#  {'linkName': 'dsg-habitat',
#   'linkValue': 'Benthic, hard substrate.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-habitat',
#   'linkValue': 'Benthic, soft sediment.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-habitat', 'linkValue': 'Benthic.', 'toConcept': 'self'},
#  {'linkName': 'dsg-habitat',
#   'linkValue': 'Benthopelagic.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-habitat', 'linkValue': 'Demersal.', 'toConcept': 'self'},
#  {'linkName': 'dsg-habitat', 'linkValue': 'nil', 'toConcept': 'self'},
#  {'linkName': 'dsg-habitat', 'linkValue': 'Pelagic.', 'toConcept': 'self'},
#  {'linkName': 'dsg-molecular-data-consultant',
#   'linkValue': 'Greg Rouse, Scripps Institute of Oceanography.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-molecular-data-consultant',
#   'linkValue': 'nil',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-range', 'linkValue': 'Antarctic.', 'toConcept': 'self'},
#  {'linkName': 'dsg-range', 'linkValue': 'Arctic.', 'toConcept': 'self'},
#  {'linkName': 'dsg-range', 'linkValue': 'Atlantic.', 'toConcept': 'self'},
#  {'linkName': 'dsg-range', 'linkValue': 'Cosmopolitan.', 'toConcept': 'self'},
#  {'linkName': 'dsg-range', 'linkValue': 'nil', 'toConcept': 'self'},
#  {'linkName': 'dsg-range', 'linkValue': 'Pacific.', 'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Agassiz, A. and H.L. Clark (1907). Memoirs of the Museum of '
#                'Comparative Zoolology, 34: 37.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Ahearn, C.G. (1995). Catalog of the type specimens of seastars '
#                '(Echinodermata: Asteroidea) in the National Museum of Natural '
#                'History, Smithsonian Institution. Smithsonian Contributions to '
#                'Zoology, 572: 1-59.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Anderson, F.E. (2000). Phylogenetic relationships among '
#                'loliginid squids (Cephalopoda: Myopsida) based on analyses of '
#                'multiple data sets. Zoological Journal of the Linnean Society, '
#                '130: 603-634.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Anderson, M.E. (1994). Systematics and osteology of the '
#                'Zoarcidae (Teleostei: Perciformes). Ichthyological Bulletin. '
#                'J.L.B. Smith Institute of Ichthyology, (60):1-120.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Baba, K. (2005). Deep-sea chirostylid and galatheid '
#                'crustaceans (Decapoda: Anomura) from the Indo-West Pacific, '
#                'with a list of species. Galathea Reports, 20: 1–317.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Barry, J.P. and R. Kochevar (1999). Calyptogena diagonalis, a '
#                'new vesicomyid bivalve from subduction zone cold seeps in the '
#                'Eastern North Pacific. The Veliger, 42(2): 117-123.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Barry, J.P., H.G. Greene, D.L. Orange, C.H. Baxter, B.H. '
#                'Robison, R.E. Kochevar, J.W. Nybakken, D.L. Reed, and C.M. '
#                'McHugh (1996). Biologic and geologic characteristics of cold '
#                'seeps in Monterey Bay, California. Deep-Sea Research, I, '
#                '43(11-12): 1739-1762.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Barry, J.P., J.R. Taylor, L.A. Kuhnz, and A.P. De Vogelaere '
#                '(2016). Symbiosis between the holothurian Scotoplanes sp. A '
#                'and the lithodid crab Neolithodes diomedeae on a featureless '
#                'bathyal sediment plain. Mar. Ecol. 1–10. '
#                'doi:10.1111/maec.12396',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Beaulieu, S.E. (2001). Life on glass houses: sponge stalk '
#                'communities in the deep sea. Marine Biology, 138: 803-817.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Behrens, D.W. (2004). Pacific Coast Nudibranchs, Supplement '
#                'II: New species to the Pacific coast and new information on '
#                'the oldies. Proceedings of the California Academy of Sciences, '
#                '55(2): 11–54.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Biermann, C.H., B.D. Kessing, and S.R. Palumbi (2003). '
#                'Phylogeny and development of marine model species: '
#                'strongylocentrotid sea urchins. Evolution and Development, 5: '
#                '360-371.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Bizzarro J.J., K.M. Broms, M.G. Logsdon, D. A. Ebert, M.M. '
#                'Yoklavich, L.A. Kuhnz, and A.P. Summer (2014). Spatial '
#                'Segregation in Eastern North Pacific Skate Assemblages. PLoS '
#                'One, 9: 1–26. 9:e109907',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Blake, J.A., P.H. Scott, and A.L. Lissner (1996). Taxonomic '
#                'atlas of the benthic fauna of the Santa Maria Basin and '
#                'western Santa Barbara Channel: Volume 14, Miscellaneous Taxa. '
#                'Santa Barbara Museum of Natural History, Santa Barbara '
#                'California. 305 pp.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Boss, K. J. and R.D. Turner (1980). The giant white clam from '
#                'the Galápagos Rift, Calyptogena magnifica species novum. '
#                'Malacologia, 20(1): 161-194. ',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Bouchet, P. and  J.-P. Rocroi (2005). Classification and '
#                'nomenclator of gastropod families. Malacologia, 47(1-2): '
#                '1-397.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Bouchet, P. and J.P. Rocroi (2005). Classification and '
#                'nomenclator of gastropod families. Malacologia, 47(1-2): '
#                '1-397.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Bouillon, J. (1985). Essai de classification des '
#                'hydropolypes-hydromeduses (Hydrozoa-Cnidaria). Indo-Malayan '
#                'Zoology, 2(1): 29-243.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Bouillon, J., F. Pages, and J-M. Gili. New species of '
#                'benthopelagic hydromedusae from the Weddell Sea. Polar '
#                'Biology, 11(24): 839-845.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Bourlat, S.J., T. Juliusdottir, C.J. Lowe, R. Freeman, J. '
#                'Aronowicz, M. Kirschner, E.S. Lander, M. Thorndyke, H. Nakano, '
#                'A.B. Kohn, A. Heyland, L.L. Moroz, R.R. Copley, and M.J. '
#                'Telford (2006). Deuterostome phylogeny reveals monophyletic '
#                'chordates and the new phylum Xenoturbellida. Nature, 444: '
#                '85–88.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Boury-Esnault, N. and L. De Vos (1988). Caulophacus cyanae n. '
#                'sp., a new hexactinellid sponge from hydrothermal vents. '
#                'Biogeography of the genus Caulophacus Schulze, 1887. '
#                'Oceanologica Acta, Volume spécial, 8: 51-60. ',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Bradburn, M. J., A. Keller, and B. H. Horness (2011). The 2003 '
#                'to 2008 U.S. West Coast bottom trawl surveys of groundfish '
#                'resources off Washington, Oregon, and California: Estimates of '
#                'distribution, abundance, length, and age composition. U.S. '
#                'Dept. of Commerce, NOAA Tech. Memo., NMFS-NWFSC-114, 323 pp.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Bradbury, M. (1967). The Genera of Batfishes (Family '
#                'Ogcocephalidae). Copeia, 2: 399-422.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Bradbury, M. (1999). A review of the fish genus Dibranchus '
#                'with descriptions of new species and a new genus, '
#                'Solocisquama. Proceedings of the California Academy of '
#                'Sciences, 51: 259-310.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Breedy, O. and H.M. Guzman (2007). A revision of the genus '
#                'Leptogorgia Milne Edwards & Haime, 1857 (Coelenterata: '
#                'Octocorallia: Gorgoniidae) in the eastern Pacific. Zootaxa, '
#                '1419:1–90.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Butler, J.L., M.S. Love, and T. Laidig (2012). A guide to the '
#                'rockfishes, thornyheads, and scorpionfishes of the Northeast '
#                'Pacific. University of California Press, Berkeley, CA. 185 pp.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Butler, T.H. (1964). Growth, reproduction and distribution of '
#                'Pandalid shrimp in British Columbia. J. Fish. Res. Bd. Canada. '
#                '21(6):1403–1452. ',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Butler, T.H. (1964). Growth, reproduction and distribution of '
#                'Pandalid shrimp in British Columbia. Journal of the Fisheries '
#                'Research Board of Canada, 21(6): 1403-1452.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Butler, T.H. (1970). Synopsis of biological data on the prawn '
#                'Pandalus platyceros Brandt, 1851. FAO Fish. Synopsis '
#                '95:1289–1315.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Butler, T.H. (1970). Synopsis of biological data on the prawn '
#                'Pandalus platyceros Brandt, 1851. FAO Fisheries Report, 95: '
#                '1289–1315.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Cailliet, G.M., A.H. Andrews, W.W. Wakefield, G. Moreno and '
#                'K.L. Rhodes (1999). Fish fauna and habitat analyses using '
#                'trawls, camera sleds, and submersibles in benthic deep-sea '
#                'habitats off central California. Oceanologica Acta 22: '
#                '579-592.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Cailliet, G.M., A.H. Andrews, W.W. Wakefield, G. Moreno, and '
#                'K.L. Rhodes (1999). Fish fauna and habitat analyses using '
#                'trawls, camera sleds, and submersibles in benthic deep-sea '
#                'habitats off central California. Oceanologica Acta, 22: '
#                '579-592.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Cairns, S. (2002). Common and Scientific Names of Aquatic '
#                'Invertebrates from the U.S. and Canada; Cnidaria and '
#                'Ctenophora, 2nd ed. American Fisheries Society Special Pub. '
#                '28. American Fisheries Society, Bethesda, Maryland.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Cairns, S.D. (1994). Scleractinia of the Temperate North '
#                'Pacific. Smithsonian Contributions to Zoology, 557: 150 pp.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Cairns, S.D. (2007). Calcaxonian Octocorals (Cnidaria; '
#                'Anthozoa) from Eastern Pacific Seamounts. Proceedings of the '
#                'California Academy of Sciences, 58(25): 511-541.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Cairns, S.D. and F.M. Bayer (2008). A review of the '
#                "Octocorallia (Cnidaria: Anthozoa) from Hawai'i and adjacent "
#                'seamounts: the genus Narella Gray, 1870. Pacific Science, '
#                '62(1): 85-115.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Caruso J.H., H. Ho, and T.W. Pietsch (2006). Chaunacops '
#                'Garman, 1899, a Senior Objective Synonym of Bathychaunax '
#                'Caruso, 1989 (Lophiiformes: Chaunacoidei: Chaunacidae). '
#                'Copeia, 2006(1): 120–121.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Castro-Aguirre, J.L. and H. Espinosa Perez (1996). Listados '
#                'faunísticos de México. VII. Catálogo sistemático de las rayas '
#                'y especies afines de México. (Chondrichthyes: Elasmobranchii: '
#                'Rajiformes: Batoideiomorpha). Universidad Nacional Autonoma de '
#                'Mexico, Mexico. 75 pp.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Child, C.A. (1987). Ammothea verenae and Sericosura venticola, '
#                'two new hydrothermal vent-associated pycnogonids from the '
#                'northeast Pacific, Proceedings of the Biological Society of '
#                'Washington, 100(4): 892–901.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Clark, A.M. and M.E. Downey (1992). Starfishes of the '
#                'Atlantic. Chapman & Hall Identification Guides, 3. Chapman & '
#                'Hall. London, UK. 794 pp.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Clark, H.L. (1946). The echinoderm fauna of Australia: Its '
#                'composition and its origin. Publications Carnegie Institute '
#                'Washington, 566: 1–567.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Clark, Roger. West Coast Slope Invertebrates Juan de Fuca '
#                'Strait to Baja California (And Southern California Shelf).',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Clarke, A. and N.M. Johnston (2003). Antarctic marine benthic '
#                'diversity. Oceanography and Marine Biology, An Annual Review, '
#                '41: 47-114.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Coan, E.V. and P. Valentich-Scott (2012). Bivalve Seashells of '
#                'Tropical West America. Marine Bivalve Mollusks from Baja '
#                'California to Northern Perú. Santa Barbara Museum of Natural '
#                'History Monographs, 6. Santa Barbara Museum of Natural '
#                'History, Santa Barbara, California. 1258 pp.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Coan, E.V., P. Valentich-Scott, and F.R. Bernard (2000). '
#                'Bivalve Seashells of Western North America. Santa Barbara '
#                'Museum of Natural History Monographs. Santa Barbara Museum of '
#                'Natural History. Santa Barbara, California. 764 pp.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Cohen, D.M. (1963). A new genus and species of bathypelagic '
#                'ophidioid fish from the western North Atlantic. Breviora, 196: '
#                '1-8.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Cohen, D.M., T. Inada, T. Iwamoto, and N. Scialabba (1990). '
#                'Gadiform Fishes of the World (Order Gadiformes). An annotated '
#                'and illustrated catalogue of cods, hakes, grenadiers and other '
#                'gadiform fishes known to date. FAO Fisheries Synopsis No. 125, '
#                'FAO Species Catalogue, 10: 442 pp.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Collins M.A. and R. Villanueva (2006). Taxonomy, ecology and '
#                'behaviour of the cirrate octopods. Oceanography and Marine '
#                'Biology: An annual review, 44: 277-322.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Collins, J.S.H., A.J. Ross, G. Genzano, and H. Mianzan (2006). '
#                'Earleria gen. nov. & Gabriella gen. nov., replacement names '
#                'for Foersteria Arai & Brinckmann-Voss, 1980 (Cnidaria, '
#                'Hydrozoa, Mitrocomidae Mitrocomidae) and Foersteria Wehner, '
#                '1988 (Crustacea, Decapoda, Prosopide), junior homonyms of '
#                'Foersteria Szépligeti, 1896 (Insecta, Hymenoptera, '
#                'Braconidae). Bulletin of the Mizunami Fossil Museum, 33: '
#                '125–126.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Compagno, L., M. Dando, and S. Fowler (2005). Sharks of the '
#                'World. Princeton University Press. Princeton, New Jersey. 368 '
#                'pp.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Compagno, L.J.V. (1984). Sharks of the World: An annotated and '
#                'illustrated catalogue of shark species known to date. FAO '
#                'Fisheries Synopsis, 125(4), Part 1.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Cooper, J.A. and F. Chapleau (1998). Monophyly and '
#                'intrarelationships of the family Pleuronectidae '
#                '(Pleuronectiformes), with a revised classification. Fishery '
#                'Bulletin, 96(4): 686-726.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Costello, M.J. et al., Eds. (2001). European register of '
#                'marine species: a check-list of the marine species in Europe '
#                'and a bibliography of guides to their identification. '
#                'Collection Patrimoines Naturels, 50',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Dawson, J. K. 1968. Chaetognaths from the Arctic Basin, '
#                'including the description of a new species of Heterokrohnia. '
#                'Bull. S. Calif. Acad. Sci. 67:112-124.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Dolganov, V.N. (1999). Geographical and bathymetric '
#                'distribution of the skates of the Rajidae Family in the far '
#                'eastern seas of Russia and adjacent waters. Journal of '
#                'Ichthyology 39(4): 340-342.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Donaldson W. and S. Byersdorfer (2005). Biological field '
#                'techniques for lithodid crabs. Sea Grant, University of Alaska '
#                'Fairbanks. 76 pp.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Drazen, J.C., J.R. Friedman, N.E. Condon, E.J. Aus, M.E. '
#                'Gerringer, A.A. Keller, and M.E. Clarke (2015). Enzyme '
#                'activities of demersal fishes from the shelf to the abyssal '
#                'plain. Deep Sea Research Part I: Oceanographic Research '
#                'Papers, 100: 117-126.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'dsg-reference | self | Desbruyères, D. and L. Laubier (1980). '
#                'Alvinella pompejana gen. sp. nov., Ampharetidae aberrant des '
#                'sources hydrothermales de la ride Est-Pacifique. Oceanologica '
#                'Acta, 3: 267-274.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Eash-Loucks, W.E., and D.G. Fautin (2012). Taxonomy and '
#                'distribution of sea anemones (Cnidaria: Actiniaria and '
#                'Corallimorpharia) from deep water of the northeastern Pacific. '
#                'Zootaxa, 3375:1-80.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Ebert, D. (2003). Sharks, rays, and chimeras of California. '
#                'University of California Press, Berkeley, California. 284 pp.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Eschmeyer, W.N. (ed) (2015). Catalog of Fishes: Genera, '
#                'Species, References. Electronic version: '
#                'http://researcharchive.calacademy.org/research/Ichthyology/catalog/fishcatmain.asp ',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Eschmeyer, W.N., E.S. Herald, and H. Hammann (1983). A field '
#                'guide to Pacific coast fishes of North America. Houghton '
#                'Mifflin Company, Boston, Massachusetts. 336 pp.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Fauchald, K. (1977). The polychaete worms: definitions and '
#                'keys to the orders, families, and genera. Natural History '
#                'Museum of Los Angeles County, Science Series 28.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Fauchald, K., and G. W. Rouse. (1997). Polychaete systematics: '
#                'Past and present. Zoologica Scripta, 26(2): 71-138.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Fautin, D.G. and C. Hand (2000). Metridium farcimen, the valid '
#                'name of a common North Pacific sea anemone. Proceedings of the '
#                'Biological Society of Washington, 113(4): 1151-1161.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Fautin, D.G., F.G. Hochberg, and J. Ljubenkov (1998). '
#                'Taxonomic atlas of the benthic fauna of the Santa Maria Basin '
#                'and western Santa Barbara Channel Volume 3: The Cnidaria. '
#                'Santa Barbara Museum of Natural History.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Fischer, W., F. Krupp, W. Schneider, C. Sommer, K.E. '
#                'Carpenter, and V.H. Niem (1995). Guia FAO para la '
#                'identificación de especies para los fines de la pesca. '
#                'Pacifico centro-oriental. Organización de las Naciones Unidas '
#                'para la Agricultura y la Alimentación, Roma. v2: 563 pp.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Fitch, J.E. and R.J. Lavenberg (1968). Deep-water teleostean '
#                'fishes of California. California Natural History Guides: 25,  '
#                'University of California Press, Berkeley and Los Angeles, '
#                'California. 115 p.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Gaither, M. R., B. Violi, H. W. I.  Gray, F. Neat, J. C. '
#                'Drazen, R. Dean Grubbs, A. Roa-Varón, T. Sutton, and A. Rus '
#                'Hoelzel (2016). Depth as a driver of evolution in the deep '
#                'sea: Insights from grenadiers (Gadiformes: Macrouridae) of the '
#                'genus Coryphaenoides. Molecular Phylogenetics and Evolution. '
#                'http://doi.org/10.1016/j.ympev.2016.07.027',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Glover, A.G., E. Goetze, T.G. Dahlgren, and C.R. Smith (2005). '
#                'Morphology, reproductive biology and genetic structure of the '
#                'whale-fall and hydrothermal vent specialist, Bathykurila '
#                'guaymasensis, Pettibone 1989 (Annelida: Polynoidae). Marine '
#                'Ecology, 26: 223-234.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Goddard, J. (2000). Tritonia festiva (Stearns, 1873). Sea Slug '
#                'Forum. Australian Museum, Sydney, Australia.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Godeaux, J.E.A. (1998). The genus Doliolina (Thaliacea: '
#                'Doliolida). Journal of Plankton Research, 20(9): 1757-1766.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'González-Romero, S., H. Reyes-Bonilla, and S.D. Cairns (2008). '
#                'Range extensions of three species of the family '
#                'Caryophylliidae (Scleractinia) in the eastern Pacific Ocean. '
#                'JMBA2-Biodiversity Records, 2pp.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Gooday, A.J. (1988). The genus Bathysiphon (Protista, '
#                'Foraminiferida) in the NE Atlantic: Revision of some species '
#                'described by de Folin (1886). Journal of Natural History, '
#                '22(1): 71-93.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Grange, L.J., C.R. Smith, D. J. Lindsay, B. Bentlage, and M.J. '
#                'Youngbluth (2017). High Abundance of the Epibenthic '
#                'Trachymedusa Ptychogastria polaris Allman, 1878 (Hydrozoa, '
#                'Trachylina) in Subpolar Fjords along the West Antarctic '
#                'Peninsula. PLoS One 12, e0168648. '
#                'doi:10.1371/journal.pone.0168648 ',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Grasshoff, M. (1981). The deep-water Gorgonaria, Pennatularia '
#                'and Antipatharia of the Bay of Biscay (Cnidaria, Anthozoa). '
#                'Results of the French Expeditions Biogas, Polygas, Geomanche, '
#                'Incal, Noratlante and of the cruises of R.V. Thalassa. 1. '
#                'General Information. Bulletin du Museum national d’Histoire '
#                'naturelle (France). 4e serie. Section A. Zoologie, biologie, '
#                'et ecologie animales. Paris 3(3): 731–766.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Grigg, R.W. 1974. Distribution and abundance of precious '
#                'corals in Hawaii. Proceedings of the Second International '
#                'Symposium on Coral Reefs. Vol.2.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Haddock, S.H.D., C.W. Dunn, P.R. Pugh, and C.E. Schnitzler '
#                '(2005). Bioluminescent and red-fluorescent lures in a deep-sea '
#                'siphonophore. Science, 309: 263.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Hajdu, E. and J. Vacelet (2002). Family Cladorhizidae Dendy, '
#                '1922. In: Systema Porifera. A guide to the classification of '
#                'sponges, edited by Hooper, J.N.A. and R.W.M. Van Soest. Kluwer '
#                'Academic/ Plenum Publishers, New York, Boston, Dordrecht, '
#                'London, pp. 636-641.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Hajdu, E., R.W.M. Van Soest, and J.N.A. Hooper (1994). '
#                'Proposal for a phylogenetic subordinal classification of '
#                'poecilosclerid sponges. In: Sponges in time and space, edited '
#                'by van Soest, R.W.M., Th.M.G van Kempen, and J.-C. Braekman. '
#                'Balkema, Rotterdam, pp. 1-515.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Hamel, J.F. (2013). Paelopatides confundens. The IUCN Red List '
#                'of Threatened Species 2013: e.T180325A1615261. '
#                'http://dx.doi.org/10.2305/IUCN.UK.2013-1.RLTS.T180325A1615261.en. '
#                'Downloaded on 19 October 2016.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Hansen, B. (1975). Scientific results of the Danish deep-sea '
#                'expedition round the world 1950-52. Systematics and biology of '
#                'the deep-sea holothurians. Part I. Elasipoda. Galathea Report, '
#                '13: 1-262.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Hansen, H.J. (1916). Crustacea Malacostraca III. V. The order '
#                'Isopoda. Danish Ingolf Expedition, 3: 1-262.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Hartwick, B. (1984). Ecological studies of Octopus dofleini '
#                '(Wueller) on the west coast of British Columbia.  Journal of '
#                'Shellfish Research, 4(1): 91.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Hayward, P.J. and J.S. Ryland, editors (1990). The marine '
#                'fauna of the British Isles and North-West Europe, Vol 1. '
#                'Introduction and protozoans to arthropods. Clarendon Press, '
#                'Oxford. 627 pp.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Heezen, B.C. and C. Hollister (1971). The Face of the Deep. '
#                'Oxford University Press, New York, London, Toronto. 669 pp. ',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Heezen, B.C. and C.D. Hollister (1971). The Face of the Deep. '
#                'New York, London, Toronto: Oxford University Press. 669 pp.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Hendrickx, M.E., Mah, C., and Zarrate-Montes, C.M. (2011). '
#                'Deep-water Asteroidea (Echinodermata) collected during the '
#                'TALUD cruises in the Gulf of California, Mexico. Revista '
#                'mexicana de biodiversidad, 82(3): 798–824.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Hendrycks, E.A. (2007). A new species of Valettiopsis Holmes, '
#                '1908 (Crustacea: Gammaridea: Lysianassoidea) from abyssal '
#                'waters off California. Zootaxa, 1501: 45–56.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Herring, P.J. (1987). Systematic distribution of '
#                'bioluminescence in living organisms. J Biolumin Chemilumin '
#                '1:147–163.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Hessle, C. (1917). Zur Kenntnis der terebellomorphen '
#                'Polychaeten. Zoologiska bidrag från Uppsala, 5: 39-258.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Hewitt, C.L. and J.R.H. Goddard (2001). A new species of large '
#                'and highly contractile hydroid in the genus Candelabrum '
#                '(Hydrozoa: Anthoathecatae) from southern Oregon, U.S.A. '
#                'Canadian Journal of Zoology, 79(12).',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Hoff, G.R., D.E. Stevenson, and J.W. Orr (2015). Guide to the '
#                'Gadiform Fishes of the eastern North Pacific. U.S. Dep. '
#                'Commer., NOAA Tech. Memo. NMFS-AFS-309, 68 pp. '
#                'doi:10.7289/V5/TM-AFSC-309.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Hoff, G.R., T.W. Buckley, J.C. Drazen, and K.M. Duncan (2000). '
#                'Biology and ecology of Nezumia liolepis and N. stelgidolepis '
#                'from the west coast of North America. Journal of Fish Biology, '
#                '57: 662–680.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Holland, N.D. (2009). A new deep-sea species of epibenthic '
#                'acorn worm (Hemichordata, Enteropneusta). Zoosystema, 31(2): '
#                '333-346.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Holland, N.D., D.A. Clague, D.P. Gordon, A. Gebruk, D.L. '
#                "Pawson, and M. Vecchione (2005). 'Lophenteropneust' hypothesis "
#                'refuted by collection and photos of new deep-sea '
#                'hemichordates. Nature, 434: 374-376.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Holland, N.D., L.A. Kuhnz, and K.J. Osborn (2012). Morphology '
#                'of a new deep-sea acorn worm (Class Enteropneusta, Phylum '
#                'Hemichordata): A part-time demersal drifter with externalized '
#                'ovaries. Journal of Morphology, 273(7): 661-671.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Hooper, J.N.A.; Van Soest, R.W.M. (Ed.) (2002). Systema '
#                'Porifera: a guide to the classification of Sponges. Kluwer '
#                'Academic/Plenum Publishers: New York, NY (USA). ISBN '
#                '0-306-47260-0. xix, 1-1101, 1103-1706 (2 volumes) pp.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Hopcroft, R.R. and B.H. Robison (1999). A new mesopelagic '
#                'larvacean, Mesochordaeus erythrocephalus, sp. nov., from '
#                'Monterey Bay, with a description of its filtering house. '
#                'Journal of Plankton Research, 21: 1923-1937.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'http://www.mexfish.com/mexico',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Hull, P.M., K.J. Osborn, R.D. Norris, and B.H. Robison (2011). '
#                'Seasonality and depth distribution of a mesopelagic '
#                'foraminifer, Hastigerinella digitata, in Monterey Bay, '
#                'California. Limnology and Oceanography. 56 (2): 562-576.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Ishihara, H., M. Treloar, P.H.F. Bor, H. Senou, and C.H. Jeong '
#                '(2012). The Comparative Morphology of Skate Egg Capsules '
#                '(Chondrichthyes: Elasmobranchii: Rajiformes). Bulletin of the '
#                'Kanagawa Prefectural Museum of Natural History, 44: 9-25.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Iwamoto, T. and D.L. Stein (1974). A Systematic Review of the '
#                'Rattail Fishes (Macrouridae: Gadiformes) from Oregon and '
#                'adjacent waters. Occasional Papers of the California Academy '
#                'of Sciences, 111: 1-79.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Iwamoto, T., and D.L. Stein (1974). A Systematic Review of the '
#                'Rattail Fishes (Macrouridae:Gadiformes) from Oregon and '
#                'Adjacent Waters. Occasional Papers of the California Academy '
#                'of Sciences 111:1-79.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Jadamec, L., W. Donaldson, and P. Cullenberg (1999). '
#                'Biological field techniques for Chionoecetes crabs. University '
#                'of Alaska Sea Grant. AK-SG-99-02, Fairbanks. 80 pp.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'James, K.C., D.A. Ebert, D.J. Long, and D.A. Didier (2009). A '
#                'new species of chimaera, Hydrolagus melanophasma sp. nov. '
#                '(Chondrichthyes: Chimaeriformes: Chimaeridae), from the '
#                'eastern North Pacific. Zootaxa, 2218: 59–68.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Jamieson, A.J., I.G. Priede, and J. Craig (2012). '
#                'Distinguishing between the abyssal macrourids\xa0'
#                'Coryphaenoides yaquinae\xa0and\xa0C. armatus\xa0from\xa0in '
#                'situ\xa0photography.\xa0Deep-Sea Research Part I, 64: 78-85.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Jensen, G.C. (1995). Pacific Coast Crabs and Shrimps. Sea '
#                'Challengers, Monterey, California. 87 pp.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Johnsen S., T.M. Frank, S.H.D. Haddock, E.A. Widder, and C.G. '
#                'Messing (2012). Light and vision in the deep-sea benthos: I. '
#                'Bioluminescence at 500-1000 m depth in the Bahamian Islands. J '
#                'Exp Biol 215:3335–3343',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Johnson S.B., A. Warén, R.W. Lee, Y. Kano, A. Kaim, A. Davis, '
#                'E.E. Strong, and R.C. Vrijenhoek (2010). Rubyspira, new genus '
#                'and two new species of bone-eating deep-sea snails with '
#                'ancient habits. Biological Bulletin, 219: 166-177.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Johnson, S.B., C.R. Young, W.J. Jones, A. Waren, and R.C. '
#                'Vrijenhoek (2006). Migration, isolation, and speciation of '
#                'hydrothermal vent limpets (Gastropoda; Lepetodrilidae) across '
#                'the Blanco Transform Fault. Biological Bulletin, 210: 140-157.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Jones, W.J. and E. Macpherson (2007). Molecular phylogeny of '
#                'the East Pacific Squat Lobsters of the genus Munidopsis '
#                '(Decapoda: Galatheidae) with the descriptions of seven new '
#                'species. Journal of Crustacean Biology, 27: 477-501.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Jones, W.J. and Macpherson, E. (2007). Molecular phylogeny of '
#                'the East Pacific squat lobsters of the genus Munidopsis '
#                '(Decapoda: Galatheidae) with the descriptions of seven new '
#                'species. Journal of Crustacean Biology. Vol. 27, no. 3, pp. '
#                '477-50.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Kahn, A.S., H.A. Ruhl, and K.L. Smith Jr. (2012). Temporal '
#                'changes in deep-sea sponge populations are correlated to '
#                'changes in surface climate and food supply. Deep Sea Research '
#                'Part I: Oceanographic Research Papers, 70: 36-41.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Kahn, A.S., J.B. Geller, H.M. Reiswig, and K.L. Smith Jr. '
#                '(2013). Bathydorus laniger and Docosaccus maculatus '
#                '(Lyssacinosida; Hexactinellida): Two new species of glass '
#                'sponge from the abyssal eastern North Pacific Ocean. Zootaxa, '
#                '3646(4): 386-400.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Kastelle, C.R., D.M. Anderi, D.K. Kimura, and C.G. Johnston '
#                '(2008). Age validation of Microstomus pacificus by means of '
#                'bomb radiocarbon. Fisheries Bulletin, 106: 375–385.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
#   'linkValue': 'Kensley, B. (1996). Systematics and distribution of the genus '
#                'Calocarides (Crustacea: Decapoda: Axiidae). Proceedings of the '
#                'Biological Society of Washington, 109: 53-69.',
#   'toConcept': 'self'},
#  {'linkName': 'dsg-reference',
# ...
#  {'linkName': 'perspective', 'linkValue': 'partly-hidden', 'toConcept': 'self'},
#  {'linkName': 'perspective',
#   'linkValue': 'vacating field of view',
#   'toConcept': 'self'},
#  {'linkName': 'perspective', 'linkValue': 'wide-shot', 'toConcept': 'self'},
#  {'linkName': 'pitted', 'linkValue': 'nil', 'toConcept': 'nil'},
#  {'linkName': 'population-aggregation',
#   'linkValue': 'nil',
#   'toConcept': 'self'},
#  {'linkName': 'population-density', 'linkValue': 'dense', 'toConcept': 'self'},
#  {'linkName': 'population-density',
#   'linkValue': 'moderate',
#   'toConcept': 'self'},
#  {'linkName': 'population-density', 'linkValue': 'sparse', 'toConcept': 'self'},
#  {'linkName': 'population-dispersal',
#   'linkValue': 'colony',
#   'toConcept': 'self'},
#  {'linkName': 'population-dispersal',
#   'linkValue': 'community',
#   'toConcept': 'self'},
#  {'linkName': 'population-dispersal',
#   'linkValue': 'individual',
#   'toConcept': 'self'},
#  {'linkName': 'population-dispersal',
#   'linkValue': 'school',
#   'toConcept': 'self'},
#  {'linkName': 'population-dispersal',
#   'linkValue': 'shoal',
#   'toConcept': 'self'},
#  {'linkName': 'population-quantity', 'linkValue': '999', 'toConcept': 'self'},
#  {'linkName': 'population-quantity', 'linkValue': 'nil', 'toConcept': 'self'},
#  {'linkName': 'posture', 'linkValue': 'closed', 'toConcept': 'self'},
#  {'linkName': 'posture', 'linkValue': 'erect', 'toConcept': 'self'},
#  {'linkName': 'posture', 'linkValue': 'flytrap', 'toConcept': 'self'},
#  {'linkName': 'posture', 'linkValue': 'horizontal', 'toConcept': 'self'},
#  {'linkName': 'posture', 'linkValue': 'lying on side', 'toConcept': 'self'},
#  {'linkName': 'posture', 'linkValue': 'oblique', 'toConcept': 'self'},
#  {'linkName': 'posture', 'linkValue': 'open', 'toConcept': 'self'},
#  {'linkName': 'posture', 'linkValue': 'standing', 'toConcept': 'self'},
#  {'linkName': 'posture', 'linkValue': 'vertical', 'toConcept': 'self'},
#  {'linkName': 'puckering', 'linkValue': 'nil', 'toConcept': 'nil'},
#  {'linkName': 'pulsing', 'linkValue': 'nil', 'toConcept': 'nil'},
#  {'linkName': 'pursuing', 'linkValue': 'nil', 'toConcept': 'physical object'},
#  {'linkName': 'raiding', 'linkValue': 'nil', 'toConcept': 'nil'},
#  {'linkName': 'regenerating',
#   'linkValue': 'nil',
#   'toConcept': 'physical object'},
#  {'linkName': 'relative-length', 'linkValue': 'long', 'toConcept': 'self'},
#  {'linkName': 'relative-length', 'linkValue': 'medium', 'toConcept': 'self'},
#  {'linkName': 'relative-length', 'linkValue': 'short', 'toConcept': 'self'},
#  {'linkName': 'relative-placement', 'linkValue': 'aboral', 'toConcept': 'self'},
#  {'linkName': 'relative-placement',
#   'linkValue': 'anterior',
#   'toConcept': 'self'},
#  {'linkName': 'relative-placement', 'linkValue': 'apex', 'toConcept': 'self'},
#  {'linkName': 'relative-placement', 'linkValue': 'axis', 'toConcept': 'self'},
#  {'linkName': 'relative-placement',
#   'linkValue': 'centered',
#   'toConcept': 'self'},
#  {'linkName': 'relative-placement', 'linkValue': 'deep', 'toConcept': 'self'},
#  {'linkName': 'relative-placement', 'linkValue': 'distal', 'toConcept': 'self'},
#  {'linkName': 'relative-placement', 'linkValue': 'dorsal', 'toConcept': 'self'},
#  {'linkName': 'relative-placement',
#   'linkValue': 'encrusting',
#   'toConcept': 'self'},
#  {'linkName': 'relative-placement', 'linkValue': 'high', 'toConcept': 'self'},
#  {'linkName': 'relative-placement', 'linkValue': 'inner', 'toConcept': 'self'},
#  {'linkName': 'relative-placement',
#   'linkValue': 'lateral',
#   'toConcept': 'self'},
#  {'linkName': 'relative-placement', 'linkValue': 'left', 'toConcept': 'self'},
#  {'linkName': 'relative-placement', 'linkValue': 'low', 'toConcept': 'self'},
#  {'linkName': 'relative-placement', 'linkValue': 'margin', 'toConcept': 'self'},
#  {'linkName': 'relative-placement', 'linkValue': 'middle', 'toConcept': 'self'},
#  {'linkName': 'relative-placement', 'linkValue': 'oral', 'toConcept': 'self'},
#  {'linkName': 'relative-placement',
#   'linkValue': 'parallel',
#   'toConcept': 'self'},
#  {'linkName': 'relative-placement',
#   'linkValue': 'posterior',
#   'toConcept': 'self'},
#  {'linkName': 'relative-placement',
#   'linkValue': 'proximal',
#   'toConcept': 'self'},
#  {'linkName': 'relative-placement', 'linkValue': 'right', 'toConcept': 'self'},
#  {'linkName': 'relative-placement',
#   'linkValue': 'shallow',
#   'toConcept': 'self'},
#  {'linkName': 'relative-placement',
#   'linkValue': 'surface',
#   'toConcept': 'self'},
#  {'linkName': 'relative-placement',
#   'linkValue': 'underside',
#   'toConcept': 'self'},
#  {'linkName': 'relative-placement',
#   'linkValue': 'unusual',
#   'toConcept': 'self'},
#  {'linkName': 'relative-placement',
#   'linkValue': 'ventral',
#   'toConcept': 'self'},
#  {'linkName': 'relative-shape', 'linkValue': 'blunt', 'toConcept': 'self'},
#  {'linkName': 'relative-shape', 'linkValue': 'bulbous', 'toConcept': 'self'},
#  {'linkName': 'relative-shape', 'linkValue': 'elongate', 'toConcept': 'self'},
#  {'linkName': 'relative-shape', 'linkValue': 'fat', 'toConcept': 'self'},
#  {'linkName': 'relative-shape', 'linkValue': 'flat', 'toConcept': 'self'},
#  {'linkName': 'relative-shape', 'linkValue': 'inflated', 'toConcept': 'self'},
#  {'linkName': 'relative-shape', 'linkValue': 'narrow', 'toConcept': 'self'},
#  {'linkName': 'relative-shape', 'linkValue': 'pointed', 'toConcept': 'self'},
#  {'linkName': 'relative-shape', 'linkValue': 'rounded', 'toConcept': 'self'},
#  {'linkName': 'relative-shape', 'linkValue': 'skinny', 'toConcept': 'self'},
#  {'linkName': 'relative-shape', 'linkValue': 'steep', 'toConcept': 'self'},
#  {'linkName': 'relative-shape', 'linkValue': 'thick', 'toConcept': 'self'},
#  {'linkName': 'relative-shape', 'linkValue': 'uniform', 'toConcept': 'self'},
#  {'linkName': 'relative-size', 'linkValue': 'large', 'toConcept': 'self'},
#  {'linkName': 'relative-size', 'linkValue': 'medium', 'toConcept': 'self'},
#  {'linkName': 'relative-size', 'linkValue': 'small', 'toConcept': 'self'},
#  {'linkName': 'reproducing', 'linkValue': 'nil', 'toConcept': 'nil'},
#  {'linkName': 'respiring', 'linkValue': 'nil', 'toConcept': 'nil'},
#  {'linkName': 'retracting', 'linkValue': 'nil', 'toConcept': 'physical object'},
#  {'linkName': 'retreating', 'linkValue': 'nil', 'toConcept': 'nil'},
#  {'linkName': 'retrieved-by', 'linkValue': 'nil', 'toConcept': 'equipment'},
#  {'linkName': 'rotating', 'linkValue': 'nil', 'toConcept': 'nil'},
#  {'linkName': 'sample-disposition', 'linkValue': 'nil', 'toConcept': 'self'},
#  {'linkName': 'sample-reference', 'linkValue': '0', 'toConcept': 'self'},
#  {'linkName': 'sampled-by', 'linkValue': 'nil', 'toConcept': 'equipment'},
#  {'linkName': 'sampled-by-certainty',
#   'linkValue': 'maybe',
#   'toConcept': 'self'},
#  {'linkName': 'schooling', 'linkValue': 'nil', 'toConcept': 'nil'},
#  {'linkName': 'shape-arrangement', 'linkValue': 'bedded', 'toConcept': 'self'},
#  {'linkName': 'shape-arrangement',
#   'linkValue': 'branched',
#   'toConcept': 'self'},
#  {'linkName': 'shape-arrangement', 'linkValue': 'chain', 'toConcept': 'self'},
#  {'linkName': 'shape-arrangement',
#   'linkValue': 'convoluted',
#   'toConcept': 'self'},
#  {'linkName': 'shape-arrangement', 'linkValue': 'draped', 'toConcept': 'self'},
#  {'linkName': 'shape-arrangement',
#   'linkValue': 'encrusting',
#   'toConcept': 'self'},
#  {'linkName': 'shape-arrangement',
#   'linkValue': 'flexible',
#   'toConcept': 'self'},
#  {'linkName': 'shape-arrangement', 'linkValue': 'folded', 'toConcept': 'self'},
#  {'linkName': 'shape-arrangement', 'linkValue': 'forked', 'toConcept': 'self'},
#  {'linkName': 'shape-arrangement', 'linkValue': 'jointed', 'toConcept': 'self'},
#  {'linkName': 'shape-arrangement', 'linkValue': 'jumbled', 'toConcept': 'self'},
#  {'linkName': 'shape-arrangement', 'linkValue': 'lobed', 'toConcept': 'self'},
#  {'linkName': 'shape-arrangement',
#   'linkValue': 'truncated',
#   'toConcept': 'self'},
#  {'linkName': 'shape-geometry', 'linkValue': 'angular', 'toConcept': 'self'},
#  {'linkName': 'shape-geometry', 'linkValue': 'bagpipe', 'toConcept': 'self'},
#  {'linkName': 'shape-geometry', 'linkValue': 'basket', 'toConcept': 'self'},
#  {'linkName': 'shape-geometry', 'linkValue': 'bowl', 'toConcept': 'self'},
#  {'linkName': 'shape-geometry', 'linkValue': 'chimney', 'toConcept': 'self'},
#  {'linkName': 'shape-geometry', 'linkValue': 'concretion', 'toConcept': 'self'},
#  {'linkName': 'shape-geometry', 'linkValue': 'cone', 'toConcept': 'self'},
#  {'linkName': 'shape-geometry', 'linkValue': 'crust', 'toConcept': 'self'},
#  {'linkName': 'shape-geometry', 'linkValue': 'curved', 'toConcept': 'self'},
#  {'linkName': 'shape-geometry', 'linkValue': 'fan', 'toConcept': 'self'},
#  {'linkName': 'shape-geometry', 'linkValue': 'film', 'toConcept': 'self'},
#  {'linkName': 'shape-geometry', 'linkValue': 'geniculate', 'toConcept': 'self'},
#  {'linkName': 'shape-geometry', 'linkValue': 'goiter', 'toConcept': 'self'},
#  {'linkName': 'shape-geometry',
#   'linkValue': 'irregular-form',
#   'toConcept': 'self'},
#  {'linkName': 'shape-geometry', 'linkValue': 'mat', 'toConcept': 'self'},
#  {'linkName': 'shape-geometry',
#   'linkValue': 'non-geniculate',
#   'toConcept': 'self'},
#  {'linkName': 'shape-geometry', 'linkValue': 'oval', 'toConcept': 'self'},
#  {'linkName': 'shape-geometry', 'linkValue': 'plate', 'toConcept': 'self'},
#  {'linkName': 'shape-geometry', 'linkValue': 'polygon', 'toConcept': 'self'},
#  {'linkName': 'shape-geometry', 'linkValue': 'round', 'toConcept': 'self'},
#  {'linkName': 'shape-geometry', 'linkValue': 'sheet', 'toConcept': 'self'},
#  {'linkName': 'shape-geometry', 'linkValue': 'square', 'toConcept': 'self'},
#  {'linkName': 'shape-geometry', 'linkValue': 'stellate', 'toConcept': 'self'},
#  {'linkName': 'shape-geometry', 'linkValue': 'trumpet', 'toConcept': 'self'},
#  {'linkName': 'shape-geometry', 'linkValue': 'tube', 'toConcept': 'self'},
#  {'linkName': 'shape-geometry', 'linkValue': 'vase', 'toConcept': 'self'},
#  {'linkName': 'shape-geometry', 'linkValue': 'vermiform', 'toConcept': 'self'},
#  {'linkName': 'sitting', 'linkValue': 'nil', 'toConcept': 'nil'},
#  {'linkName': 'sitting-in', 'linkValue': 'nil', 'toConcept': 'physical object'},
#  {'linkName': 'spawning', 'linkValue': 'nil', 'toConcept': 'nil'},
#  {'linkName': 'state', 'linkValue': 'altered', 'toConcept': 'self'},
#  {'linkName': 'state', 'linkValue': 'empty', 'toConcept': 'self'},
#  {'linkName': 'state', 'linkValue': 'full', 'toConcept': 'self'},
#  {'linkName': 'stowed', 'linkValue': 'nil', 'toConcept': 'physical object'},
#  {'linkName': 'surface-color', 'linkValue': 'amber', 'toConcept': 'self'},
#  {'linkName': 'surface-color', 'linkValue': 'beige', 'toConcept': 'self'},
#  {'linkName': 'surface-color',
#   'linkValue': 'bioluminescent',
#   'toConcept': 'self'},
#  {'linkName': 'surface-color', 'linkValue': 'black', 'toConcept': 'self'},
#  {'linkName': 'surface-color', 'linkValue': 'blue', 'toConcept': 'self'},
#  {'linkName': 'surface-color', 'linkValue': 'brown', 'toConcept': 'self'},
#  {'linkName': 'surface-color', 'linkValue': 'dark', 'toConcept': 'self'},
#  {'linkName': 'surface-color', 'linkValue': 'green', 'toConcept': 'self'},
#  {'linkName': 'surface-color', 'linkValue': 'grey', 'toConcept': 'self'},
#  {'linkName': 'surface-color', 'linkValue': 'orange', 'toConcept': 'self'},
#  {'linkName': 'surface-color', 'linkValue': 'pink', 'toConcept': 'self'},
#  {'linkName': 'surface-color', 'linkValue': 'purple', 'toConcept': 'self'},
#  {'linkName': 'surface-color', 'linkValue': 'red', 'toConcept': 'self'},
#  {'linkName': 'surface-color', 'linkValue': 'silver', 'toConcept': 'self'},
#  {'linkName': 'surface-color', 'linkValue': 'translucent', 'toConcept': 'self'},
#  {'linkName': 'surface-color', 'linkValue': 'transparent', 'toConcept': 'self'},
#  {'linkName': 'surface-color', 'linkValue': 'white', 'toConcept': 'self'},
#  {'linkName': 'surface-color', 'linkValue': 'yellow', 'toConcept': 'self'},
#  {'linkName': 'surface-pattern', 'linkValue': 'barred', 'toConcept': 'self'},
#  {'linkName': 'surface-pattern',
#   'linkValue': 'counter-shaded',
#   'toConcept': 'self'},
#  {'linkName': 'surface-pattern', 'linkValue': 'fibrous', 'toConcept': 'self'},
#  {'linkName': 'surface-pattern', 'linkValue': 'layered', 'toConcept': 'self'},
#  {'linkName': 'surface-pattern', 'linkValue': 'mesh', 'toConcept': 'self'},
#  {'linkName': 'surface-pattern', 'linkValue': 'mottled', 'toConcept': 'self'},
#  {'linkName': 'surface-pattern',
#   'linkValue': 'shimmering',
#   'toConcept': 'self'},
#  {'linkName': 'surface-pattern', 'linkValue': 'solid', 'toConcept': 'self'},
#  {'linkName': 'surface-pattern', 'linkValue': 'spotted', 'toConcept': 'self'},
#  {'linkName': 'surface-pattern', 'linkValue': 'striped', 'toConcept': 'self'},
#  {'linkName': 'surface-texture', 'linkValue': 'coarse', 'toConcept': 'self'},
#  {'linkName': 'surface-texture', 'linkValue': 'fine', 'toConcept': 'self'},
#  {'linkName': 'surface-texture', 'linkValue': 'fleshy', 'toConcept': 'self'},
#  {'linkName': 'surface-texture',
#   'linkValue': 'gelatinous',
#   'toConcept': 'self'},
#  {'linkName': 'surface-texture', 'linkValue': 'granular', 'toConcept': 'self'},
#  {'linkName': 'surface-texture', 'linkValue': 'hard', 'toConcept': 'self'},
#  {'linkName': 'surface-texture', 'linkValue': 'hummocky', 'toConcept': 'self'},
#  {'linkName': 'surface-texture', 'linkValue': 'lumpy', 'toConcept': 'self'},
#  {'linkName': 'surface-texture', 'linkValue': 'rough', 'toConcept': 'self'},
#  {'linkName': 'surface-texture', 'linkValue': 'shaggy', 'toConcept': 'self'},
#  {'linkName': 'surface-texture', 'linkValue': 'smooth', 'toConcept': 'self'},
#  {'linkName': 'surface-texture', 'linkValue': 'soft', 'toConcept': 'self'},
#  {'linkName': 'surface-texture', 'linkValue': 'spiny', 'toConcept': 'self'},
#  {'linkName': 'surface-texture', 'linkValue': 'vesicular', 'toConcept': 'self'},
#  {'linkName': 'suspect-navigation-ctd-other-data',
#   'linkValue': 'nil',
#   'toConcept': 'self'},
#  {'linkName': 'swarming', 'linkValue': 'nil', 'toConcept': 'nil'},
#  {'linkName': 'swimming', 'linkValue': 'nil', 'toConcept': 'nil'},
#  {'linkName': 'swimming-down', 'linkValue': 'nil', 'toConcept': 'nil'},
#  {'linkName': 'swimming-up', 'linkValue': 'nil', 'toConcept': 'nil'},
#  {'linkName': 'symbiont-commensal-with',
#   'linkValue': 'nil',
#   'toConcept': 'marine organism'},
#  {'linkName': 'symbiont-host-to',
#   'linkValue': 'nil',
#   'toConcept': 'marine organism'},
#  {'linkName': 'symbiont-mutualism-with',
#   'linkValue': 'nil',
#   'toConcept': 'marine organism'},
#  {'linkName': 'symbiont-parasitized-by',
#   'linkValue': 'nil',
#   'toConcept': 'marine organism'},
#  {'linkName': 'symbiont-symbiotic-with',
#   'linkValue': 'nil',
#   'toConcept': 'marine organism'},
#  {'linkName': 'taxonomy-former-or-unaccepted-name',
#   'linkValue': 'nil',
#   'toConcept': 'self'},
#  {'linkName': 'testing', 'linkValue': 'nil', 'toConcept': 'nil'},
#  {'linkName': 'touching', 'linkValue': 'nil', 'toConcept': 'physical object'},
#  {'linkName': 'trailing', 'linkValue': 'nil', 'toConcept': 'physical object'},
#  {'linkName': 'trying', 'linkValue': 'nil', 'toConcept': 'nil'},
#  {'linkName': 'turning-around', 'linkValue': 'nil', 'toConcept': 'nil'},
#  {'linkName': 'unattaching', 'linkValue': 'nil', 'toConcept': 'nil'},
#  {'linkName': 'under', 'linkValue': 'nil', 'toConcept': 'physical object'},
#  {'linkName': 'upon', 'linkValue': 'nil', 'toConcept': 'physical object'},
#  {'linkName': 'usage-embargo-expiration',
#   'linkValue': 'indefinitely',
#   'toConcept': 'self'},
#  {'linkName': 'usage-embargo-expiration',
#   'linkValue': 'nil',
#   'toConcept': 'self'},
#  {'linkName': 'usage-embargo-specifications',
#   'linkValue': 'nil',
#   'toConcept': 'self'},
#  {'linkName': 'walking', 'linkValue': 'nil', 'toConcept': 'nil'},
#  {'linkName': 'water-quality', 'linkValue': 'clear', 'toConcept': 'self'},
#  {'linkName': 'water-quality', 'linkValue': 'murky', 'toConcept': 'self'},
#  {'linkName': 'water-quality',
#   'linkValue': 'sediment-cloudy',
#   'toConcept': 'self'},
#  {'linkName': 'water-quality',
#   'linkValue': 'turbid-green',
#   'toConcept': 'self'},
#  {'linkName': 'waving', 'linkValue': 'nil', 'toConcept': 'physical object'},
#  {'linkName': 'within', 'linkValue': 'nil', 'toConcept': 'physical object'}]
